# %% [markdown]
# # SN3 A - EI Cosmology

# %% [markdown]
# Our notebook allows to obtain the cosmological constants $\Omega_{m}$ and $\Omega_{\lambda}$ from a set of data containing the differents mesures (for different redshifts) of the apparent magnitude of a SuperNovae.
#
# We use firstly the Minuit Module to obtain fitted lightcurves and from these results, we use the MCMC method (Monte-Carlo Markov Chain) to get our cosmological constraints.
#
# In the end, we compare our results with Work Package CMB3 one's by using the MCMC Method.
#
# A bonus at the end is available at the end of the Notebook giving a bright-slower effect law and absolute magnitude law from theory only for an approximation for $z << 1$.

# %% [markdown]
# ### Import libraries

# %%
# Classical librairies
from pylab import *
import numpy as np
from matplotlib import rc
import matplotlib.pyplot as plt
import os
from scipy.interpolate import interp1d
from scipy.optimize import minimize
import pandas as pd  # For CSV export
import glob
import emcee


# Specific libraries
import cosmolib as cs

# Visuals
rc('figure',figsize=(10,5))
rc('font',size=12)
rc('text',usetex=False)

# %% [markdown]
# ### MINUIT

# %% [markdown]
# Using the Minuit Module from the librairy comsolib, the next cell return the fitted lightcurves from the data given to us (redshift, apparent magnitude and magnitude error).
#
# Using the average lightcurve data and an interpolation function, the Minuit module return the fitted values giving then the best parameters to fit the curves with only certain points.
#
# In order to reduce the $\chi^{2}$ of our results, we added an arbitrary systematic error $= 0.12$ because the SuperNovae are not perfect candles !
#
# NB : We do not consider the points for the one with a magnitude equal to zero (troncature).

# %%
# Load redshift data
redshifts = np.loadtxt('data/Data-LightCurves/EI2019-Data-LightCurves-SN-Redshifts.txt')

# Load template lightcurve
t_template, mag_template = np.loadtxt('data/Data-LightCurves/EI2019-Data-LightCurves-SN-SNI-Average_LightCurve.txt').T

# Intrinsic error parameter for SN Ia (can be adjusted)
sigma_int = 0.12

# Interpolation model for SNIa lightcurve
class SNIaLightCurve:
    def __init__(self, template_data):
        self.template_t = template_data[0]
        self.template_mag = template_data[1]
        self.interpolator = interp1d(
            self.template_t,
            self.template_mag,
            kind='linear',
            fill_value='extrapolate',
            bounds_error=False
        )
        
    def __call__(self, t, pars):
        # pars : [t0, s, mu] where:
        # t0 : time of maximum brightness
        # s : stretch parameter (brighter-slower effect)
        # mu : distance modulus
        t0, s, mu = pars
        
        # Apply time stretch and shift
        t_stretched = (t - t0) / s
        
        # Interpolate template at stretched times using scipy interpolator
        mag_intrinsic = self.interpolator(t_stretched)
        
        # Apply brighter-slower correction: -1.52*(s-1) and add distance modulus
        mag_observed = mag_intrinsic - 1.52*(s-1) + mu
        
        return mag_observed

# Initialize template lightcurve
lc_template = SNIaLightCurve([t_template, mag_template])

# Arbitrary cosmological parameters to initialize mu_guess 
cosmo_pars = {'h': 0.7, 'omega_M_0': 0.5, 'omega_lambda_0': 0.5, 'w0': -1}

# Function to fit individual supernova
def fit_supernova_lightcurve(sn_number, redshift, lc_template, sigma_int, verbose=False):
    
    # Load supernova data
    filename = f'data/Data-LightCurves/EI2019-Data-LightCurves-SN-{sn_number}_lightcurve.txt'
    if not os.path.exists(filename):
        return None
        
    data = np.loadtxt(filename)
    t_obs = data[:, 0]  # observed time
    mag_obs = data[:, 1]  # observed magnitude
    mag_err = data[:, 2]  # magnitude errors
    
    # Add intrinsic error in quadrature
    total_mag_err = np.sqrt(mag_err**2 + sigma_int**2)
    
    # Convert to rest frame time
    t_rest = t_obs / (1 + redshift)
    
    # Initial guess: t0=reasonable time of maximum brightness, s=1, mu=reasonable distance modulus for the redshift
    t0_guess = t_rest[np.argmin(mag_obs)]
    mu_guess = cs.musn1a(redshift, cosmo_pars)

    # Initial guess = [t0, s, mu]
    guess = np.array([t0_guess, 1.0, mu_guess])
    
    try:
        # Fit using Minuit with total error (including intrinsic scatter)
        result = cs.do_minuit(t_rest, mag_obs, total_mag_err, guess, 
                             functname=lc_template, verbose=verbose)
        
        fitm, fitted_values, errors, covariance, chi2, ndf = result
        
        return {
            'sn_number': sn_number,
            'redshift': redshift,
            't0': fitted_values[0],
            't0_err': errors[0],
            's': fitted_values[1],
            's_err': errors[1],
            'mu': fitted_values[2],
            'mu_err': errors[2],
            'chi2': chi2,
            'ndf': ndf,
            'chi2_reduced': chi2/ndf if ndf > 0 else np.inf,
            'sigma_int_used': sigma_int
        }
    except Exception as e:
        if verbose:
            print(f"Fitting failed for SN-{sn_number}: {e}")
        return None

# Fit all supernovae
print(f"Fitting individual supernova lightcurves with intrinsic error σ_int = {sigma_int:.3f} mag...")
fitting_results = []

for i in range(len(redshifts)):
    print(f"Fitting SN-{i}...")
    result = fit_supernova_lightcurve(i, redshifts[i], lc_template, sigma_int=sigma_int, verbose=True)
    if result is not None:
        fitting_results.append(result)
        print(f"SN-{i}: μ = {result['mu']:.3f} ± {result['mu_err']:.3f}, s = {result['s']:.3f} ± {result['s_err']:.3f}")
    print()

print(f"Successfully fitted {len(fitting_results)} supernovae")

# Display results
if fitting_results:
    print("\nFitting Results Summary:")
    print("SN\tRedshift\tμ ± σ_μ\t\ts ± σ_s\t\tχ²/ndf")
    print("-" * 70)
    for result in fitting_results:
        print(f"{result['sn_number']}\t{result['redshift']:.3f}\t\t{result['mu']:.3f} ± {result['mu_err']:.3f}\t{result['s']:.3f} ± {result['s_err']:.3f}\t{result['chi2_reduced']:.2f}")

    print(f"\nNote: All fits include intrinsic scatter σ_int = {sigma_int:.3f} mag")
# Out:
# Fitting individual supernova lightcurves with intrinsic error σ_int = 0.120 mag...
# Fitting SN-0...
# Fitting with Minuit
# Chi2 = 10.818567951653234
# ndf = 17
# Fitted values:
# [-0.25736324  1.0398069  43.65314398]
# Errors:
# [0.73809052 0.08571505 0.15611946]
# Covariance:
# [[ 0.54477761 -0.04837963 -0.07531404]
#  [-0.04837963  0.00734707  0.01301572]
#  [-0.07531404  0.01301572  0.02437329]]
# SN-0: μ = 43.653 ± 0.156, s = 1.040 ± 0.086
#
# Fitting SN-1...
# Fitting with Minuit
# Chi2 = 11.654937729241652
# ndf = 17
# Fitted values:
# [ 3.14705141  0.93476756 41.935396  ]
# Errors:
# [0.21064693 0.02911105 0.08161884]
# Covariance:
# [[0.04437213 0.00183206 0.00513074]
#  [0.00183206 0.00084745 0.00223909]
#  [0.00513074 0.00223909 0.00666163]]
# SN-1: μ = 41.935 ± 0.082, s = 0.935 ± 0.029
#
# Fitting SN-2...
# Fitting with Minuit
# Chi2 = 11.010582473465991
# ndf = 17
# Fitted values:
# [-1.88115305  1.10565668 43.73120406]
# Errors:
# [1.05467438 0.10073104 0.1657745 ]
# Covariance:
# [[ 1.11233805 -0.09020827 -0.12581558]
#  [-0.09020827  0.01014674  0.01613086]
#  [-0.12581558  0.01613086  0.02748118]]
# SN-2: μ = 43.731 ± 0.166, s = 1.106 ± 0.101
#
# Fitting SN-3...
# Fitting with Minuit
# Chi2 = 15.50997835532485
# ndf = 17
# Fitted values:
# [-0.47069807  1.02882227 44.24843725]
# Errors:
# [0.94981024 0.10820169 0.18390956]
# Covariance:
# [[ 0.90213949 -0.08541485 -0.12956872]
#  [-0.08541485  0.01170761  0.01944817]
#  [-0.12956872  0.01944817  0.03382273]]
# SN-3: μ = 44.248 ± 0.184, s = 1.029 ± 0.108
#
# Fitting SN-4...
# Fitting with Minuit
# Chi2 = 23.623069372729095
# ndf = 17
# Fitted values:
# [ 0.62811421  1.00385746 39.94433026]
# Errors:
# [0.28968455 0.03263197 0.08719979]
# Covariance:
# [[ 0.08391714 -0.00242411 -0.00310626]
#  [-0.00242411  0.00106485  0.00268293]
#  [-0.00310626  0.00268293  0.0076038 ]]
# SN-4: μ = 39.944 ± 0.087, s = 1.004 ± 0.033
#
# Fitting SN-5...
# Fitting with Minuit
# Chi2 = 23.214247313611295
# ndf = 17
# Fitted values:
# [-1.56222419  0.94416966 41.39881186]
# Errors:
# [0.53468106 0.03903258 0.08843131]
# Covariance:
# [[ 0.28588384 -0.01458604 -0.02050762]
#  [-0.01458604  0.00152354  0.00313688]
#  [-0.02050762  0.00313688  0.0078201 ]]
# SN-5: μ = 41.399 ± 0.088, s = 0.944 ± 0.039
#
# Fitting SN-6...
# Fitting with Minuit
# Chi2 = 15.709059232241364
# ndf = 17
# Fitted values:
# [ 1.51900025  1.02678504 42.55637256]
# Errors:
# [0.36884951 0.0544922  0.11820098]
# Covariance:
# [[ 0.13604996 -0.00863739 -0.01468997]
#  [-0.00863739  0.0029694   0.00623991]
#  [-0.01468997  0.00623991  0.01397147]]
# SN-6: μ = 42.556 ± 0.118, s = 1.027 ± 0.054
#
# Fitting SN-7...
# Fitting with Minuit
# Chi2 = 13.616347285086164
# ndf = 17
# Fitted values:
# [-1.14293527  0.90246854 42.35981991]
# Errors:
# [0.51998723 0.04494632 0.09861954]
# Covariance:
# [[ 0.27038672 -0.01717657 -0.02672206]
#  [-0.01717657  0.00202017  0.00411952]
#  [-0.02672206  0.00411952  0.00972581]]
# SN-7: μ = 42.360 ± 0.099, s = 0.902 ± 0.045
#
# Fitting SN-8...
# Fitting with Minuit
# Chi2 = 12.413088889768517
# ndf = 17
# Fitted values:
# [ 1.7952106   0.98718985 42.49119432]
# Errors:
# [0.3500019  0.04924125 0.11027251]
# Covariance:
# [[ 0.12250133 -0.00721694 -0.0123097 ]
#  [-0.00721694  0.0024247   0.00523493]
#  [-0.0123097   0.00523493  0.01216003]]
# SN-8: μ = 42.491 ± 0.110, s = 0.987 ± 0.049
#
# Fitting SN-9...
# Fitting with Minuit
# Chi2 = 17.915760094096804
# ndf = 17
# Fitted values:
# [-1.6856653   0.89658336 42.73067848]
# Errors:
# [0.56918866 0.04748119 0.1001155 ]
# Covariance:
# [[ 0.32397573 -0.01977952 -0.02767905]
#  [-0.01977952  0.00225446  0.00436796]
#  [-0.02767905  0.00436796  0.01002311]]
# SN-9: μ = 42.731 ± 0.100, s = 0.897 ± 0.047
#
# Fitting SN-10...
# Fitting with Minuit
# Chi2 = 10.552063289907501
# ndf = 17
# Fitted values:
# [ 0.17110218  1.02863091 43.71301586]
# Errors:
# [0.67155543 0.0797821  0.14776125]
# Covariance:
# [[ 0.4509867  -0.04055465 -0.06471843]
#  [-0.04055465  0.00636518  0.01145989]
#  [-0.06471843  0.01145989  0.02183339]]
# SN-10: μ = 43.713 ± 0.148, s = 1.029 ± 0.080
#
# Fitting SN-11...
# Fitting with Minuit
# Chi2 = 15.532546877635871
# ndf = 17
# Fitted values:
# [ 0.69328337  0.93240614 43.75389224]
# Errors:
# [0.51852492 0.07083061 0.13992148]
# Covariance:
# [[ 0.26886809 -0.02532541 -0.04286951]
#  [-0.02532541  0.00501698  0.00962466]
#  [-0.04286951  0.00962466  0.01957802]]
# SN-11: μ = 43.754 ± 0.140, s = 0.932 ± 0.071
#
# Fitting SN-12...
# Fitting with Minuit
# Chi2 = 19.975892641209636
# ndf = 17
# Fitted values:
# [-1.44382251  1.08021126 42.96247987]
# Errors:
# [0.80817863 0.07163666 0.12889537]
# Covariance:
# [[ 0.6531527  -0.04662986 -0.06665638]
#  [-0.04662986  0.00513181  0.00879496]
#  [-0.06665638  0.00879496  0.01661402]]
# SN-12: μ = 42.962 ± 0.129, s = 1.080 ± 0.072
#
# Fitting SN-13...
# Fitting with Minuit
# Chi2 = 14.581431962408107
# ndf = 17
# Fitted values:
# [-2.04185629  1.04031757 43.17894089]
# Errors:
# [0.82188363 0.07347094 0.13268557]
# Covariance:
# [[ 0.6754927  -0.04847894 -0.0700986 ]
#  [-0.04847894  0.00539798  0.00930693]
#  [-0.0700986   0.00930693  0.01760546]]
# SN-13: μ = 43.179 ± 0.133, s = 1.040 ± 0.073
#
# Fitting SN-14...
# Fitting with Minuit
# Chi2 = 9.47435728992542
# ndf = 17
# Fitted values:
# [ 0.30763213  0.90222681 43.02058767]
# Errors:
# [0.47622229 0.05424652 0.11492611]
# Covariance:
# [[ 0.22678767 -0.01770126 -0.03010049]
#  [-0.01770126  0.00294268  0.00597298]
#  [-0.03010049  0.00597298  0.01320801]]
# SN-14: μ = 43.021 ± 0.115, s = 0.902 ± 0.054
#
# Fitting SN-15...
# Fitting with Minuit
# Chi2 = 16.215438302406234
# ndf = 17
# Fitted values:
# [-0.15739265  1.16324518 43.56250531]
# Errors:
# [0.09872921 0.00908933 0.0336616 ]
# Covariance:
# [[ 9.74745776e-03 -2.27464303e-05  3.51881457e-04]
#  [-2.27464303e-05  8.26159690e-05  1.64301044e-04]
#  [ 3.51881457e-04  1.64301044e-04  1.13310362e-03]]
# SN-15: μ = 43.563 ± 0.034, s = 1.163 ± 0.009
#
# Fitting SN-16...
# Fitting with Minuit
# Chi2 = 9.911221481033454
# ndf = 17
# Fitted values:
# [ 1.30370741  0.99710947 43.94621709]
# Errors:
# [0.55747188 0.07676074 0.14694861]
# Covariance:
# [[ 0.3107749  -0.02903039 -0.04842887]
#  [-0.02903039  0.00589221  0.01099298]
#  [-0.04842887  0.01099298  0.02159389]]
# SN-16: μ = 43.946 ± 0.147, s = 0.997 ± 0.077
#
# Fitting SN-17...
# Fitting with Minuit
# Chi2 = 21.62449299233378
# ndf = 17
# Fitted values:
# [-1.38353762  1.18526931 43.72289437]
# Errors:
# [1.00147541 0.10844328 0.18303063]
# Covariance:
# [[ 1.002953   -0.0911282  -0.13642816]
#  [-0.0911282   0.01175995  0.01940933]
#  [-0.13642816  0.01940933  0.03350021]]
# SN-17: μ = 43.723 ± 0.183, s = 1.185 ± 0.108
#
# Fitting SN-18...
# Fitting with Minuit
# Chi2 = 14.336339572955799
# ndf = 17
# Fitted values:
# [-0.43216157  0.93855659 43.73477741]
# Errors:
# [0.61659842 0.07055997 0.13563005]
# Covariance:
# [[ 0.38019361 -0.03282507 -0.05265092]
#  [-0.03282507  0.00497871  0.0092226 ]
#  [-0.05265092  0.0092226   0.01839551]]
# SN-18: μ = 43.735 ± 0.136, s = 0.939 ± 0.071
#
# Fitting SN-19...
# Fitting with Minuit
# Chi2 = 10.977520827271373
# ndf = 17
# Fitted values:
# [-1.33839887  0.94016207 43.7937545 ]
# Errors:
# [0.76857565 0.07515355 0.13634125]
# Covariance:
# [[ 0.59070854 -0.0463843  -0.06778028]
#  [-0.0463843   0.00564806  0.00977122]
#  [-0.06778028  0.00977122  0.01858894]]
# SN-19: μ = 43.794 ± 0.136, s = 0.940 ± 0.075
#
# Fitting SN-20...
# Fitting with Minuit
# Chi2 = 13.62637059333711
# ndf = 17
# Fitted values:
# [-2.8403899   1.01870684 42.1750105 ]
# Errors:
# [0.72844479 0.05514886 0.10802911]
# Covariance:
# [[ 0.53063181 -0.03067311 -0.04085439]
#  [-0.03067311  0.0030414   0.00550095]
#  [-0.04085439  0.00550095  0.01167029]]
# SN-20: μ = 42.175 ± 0.108, s = 1.019 ± 0.055
#
# Fitting SN-21...
# Fitting with Minuit
# Chi2 = 12.872716149403837
# ndf = 17
# Fitted values:
# [-2.3209874   1.0366353  42.85075794]
# Errors:
# [0.09295301 0.00431953 0.03029433]
# Covariance:
# [[ 8.64026252e-03 -6.47672955e-06  5.27275819e-04]
#  [-6.47672955e-06  1.86583224e-05  4.33441978e-05]
#  [ 5.27275819e-04  4.33441978e-05  9.17746146e-04]]
# SN-21: μ = 42.851 ± 0.030, s = 1.037 ± 0.004
#
# Fitting SN-22...
# Fitting with Minuit
# Chi2 = 19.561917000056667
# ndf = 17
# Fitted values:
# [ 0.58395379  0.97086018 42.77785013]
# Errors:
# [0.49755252 0.05565572 0.1164784 ]
# Covariance:
# [[ 0.24755851 -0.01869867 -0.03129983]
#  [-0.01869867  0.00309756  0.00622323]
#  [-0.03129983  0.00622323  0.01356722]]
# SN-22: μ = 42.778 ± 0.116, s = 0.971 ± 0.056
#
# Fitting SN-23...
# Fitting with Minuit
# Chi2 = 13.323900069347866
# ndf = 17
# Fitted values:
# [-1.14229517  1.11966372 43.21069693]
# Errors:
# [0.90244935 0.08657804 0.15044316]
# Covariance:
# [[ 0.81441483 -0.06496319 -0.09645199]
#  [-0.06496319  0.00749576  0.01260649]
#  [-0.09645199  0.01260649  0.02263315]]
# SN-23: μ = 43.211 ± 0.150, s = 1.120 ± 0.087
#
# Fitting SN-24...
# Fitting with Minuit
# Chi2 = 16.857979713733602
# ndf = 17
# Fitted values:
# [-1.09088608  0.91170144 42.09241309]
# Errors:
# [0.52555924 0.04455004 0.09852488]
# Covariance:
# [[ 0.27621251 -0.01662239 -0.02558141]
#  [-0.01662239  0.00198471  0.00408417]
#  [-0.02558141  0.00408417  0.00970715]]
# SN-24: μ = 42.092 ± 0.099, s = 0.912 ± 0.045
#
# Fitting SN-25...
# Fitting with Minuit
# Chi2 = 3.4747845262387846
# ndf = 17
# Fitted values:
# [ 2.15871263  0.96278082 43.85270138]
# Errors:
# [0.37102037 0.05733608 0.11954016]
# Covariance:
# [[ 0.13765612 -0.00828305 -0.0140884 ]
#  [-0.00828305  0.00328743  0.00662775]
#  [-0.0140884   0.00662775  0.01428985]]
# SN-25: μ = 43.853 ± 0.120, s = 0.963 ± 0.057
#
# Fitting SN-26...
# Fitting with Minuit
# Chi2 = 16.147873786735563
# ndf = 17
# Fitted values:
# [ 1.50953687  1.01756451 43.13740475]
# Errors:
# [0.13127178 0.01637112 0.0474741 ]
# Covariance:
# [[0.01723228 0.00176048 0.0042994 ]
#  [0.00176048 0.00026801 0.00062747]
#  [0.0042994  0.00062747 0.00225379]]
# SN-26: μ = 43.137 ± 0.047, s = 1.018 ± 0.016
#
# Fitting SN-27...
# Fitting with Minuit
# Chi2 = 10.14403433305849
# ndf = 17
# Fitted values:
# [ 1.68655795  1.09243891 42.58415077]
# Errors:
# [0.05257602 0.01344844 0.03972968]
# Covariance:
# [[ 2.76423782e-03 -1.49649195e-05  5.08513644e-05]
#  [-1.49649195e-05  1.80860447e-04  3.87185066e-04]
#  [ 5.08513644e-05  3.87185066e-04  1.57844764e-03]]
# SN-27: μ = 42.584 ± 0.040, s = 1.092 ± 0.013
#
# Fitting SN-28...
# Fitting with Minuit
# Chi2 = 17.202003412390194
# ndf = 17
# Fitted values:
# [ 1.68072385  0.98813761 43.49696629]
# Errors:
# [0.01690215 0.01405995 0.04076367]
# Covariance:
# [[2.85682687e-04 3.14809468e-05 7.23825079e-05]
#  [3.14809468e-05 1.97682112e-04 4.08547772e-04]
#  [7.23825079e-05 4.08547772e-04 1.66167648e-03]]
# SN-28: μ = 43.497 ± 0.041, s = 0.988 ± 0.014
#
# Fitting SN-29...
# Fitting with Minuit
# Chi2 = 9.242763714996164
# ndf = 17
# Fitted values:
# [ 2.28481224  0.96969821 43.7305005 ]
# Errors:
# [0.36778303 0.05588067 0.1171047 ]
# Covariance:
# [[ 0.13526436 -0.0079957  -0.0135499 ]
#  [-0.0079957   0.00312265  0.00632444]
#  [-0.0135499   0.00632444  0.01371351]]
# SN-29: μ = 43.731 ± 0.117, s = 0.970 ± 0.056
#
# Fitting SN-30...
# Fitting with Minuit
# Chi2 = 15.470687235918998
# ndf = 17
# Fitted values:
# [ 2.80284619  1.05985002 43.66515211]
# Errors:
# [0.37890167 0.06187251 0.12592588]
# Covariance:
# [[ 0.14356647 -0.00872952 -0.01494915]
#  [-0.00872952  0.00382821  0.00757972]
#  [-0.01494915  0.00757972  0.01585733]]
# SN-30: μ = 43.665 ± 0.126, s = 1.060 ± 0.062
#
# Fitting SN-31...
# Fitting with Minuit
# Chi2 = 11.200779280600468
# ndf = 17
# Fitted values:
# [ 0.72341467  0.94751512 41.0150055 ]
# Errors:
# [0.34391814 0.03670351 0.0924823 ]
# Covariance:
# [[ 0.11827969 -0.00620392 -0.01060552]
#  [-0.00620392  0.00134715  0.00320535]
#  [-0.01060552  0.00320535  0.00855298]]
# SN-31: μ = 41.015 ± 0.092, s = 0.948 ± 0.037
#
# Fitting SN-32...
# Fitting with Minuit
# Chi2 = 8.260717459335469
# ndf = 17
# Fitted values:
# [-4.07820825  1.20919531 43.7681399 ]
# Errors:
# [0.10546344 0.02061803 0.05260746]
# Covariance:
# [[ 0.01112254 -0.00010669  0.00042893]
#  [-0.00010669  0.0004251   0.00089737]
#  [ 0.00042893  0.00089737  0.00276755]]
# SN-32: μ = 43.768 ± 0.053, s = 1.209 ± 0.021
#
# Fitting SN-33...
# Fitting with Minuit
# Chi2 = 13.313041771580075
# ndf = 17
# Fitted values:
# [-0.08465907  0.93200547 43.18043036]
# Errors:
# [0.56993722 0.05853101 0.11686553]
# Covariance:
# [[ 0.32482844 -0.0248507  -0.03951862]
#  [-0.0248507   0.00342588  0.00652266]
#  [-0.03951862  0.00652266  0.01365755]]
# SN-33: μ = 43.180 ± 0.117, s = 0.932 ± 0.059
#
# Fitting SN-34...
# Fitting with Minuit
# Chi2 = 21.696693445604563
# ndf = 17
# Fitted values:
# [ 0.99694788  0.98839819 43.2463296 ]
# Errors:
# [0.52159263 0.06767772 0.13480971]
# Covariance:
# [[ 0.27205887 -0.0234385  -0.03936505]
#  [-0.0234385   0.00458027  0.00886148]
#  [-0.03936505  0.00886148  0.01817366]]
# SN-34: μ = 43.246 ± 0.135, s = 0.988 ± 0.068
#
# Fitting SN-35...
# Fitting with Minuit
# Chi2 = 16.75288479451435
# ndf = 17
# Fitted values:
# [ 1.6575233   0.92848708 41.25973526]
# Errors:
# [0.24238296 0.03139418 0.08691343]
# Covariance:
# [[ 0.0587495  -0.00061161  0.00024099]
#  [-0.00061161  0.00098559  0.00258119]
#  [ 0.00024099  0.00258119  0.00755394]]
# SN-35: μ = 41.260 ± 0.087, s = 0.928 ± 0.031
#
# Fitting SN-36...
# Fitting with Minuit
# Chi2 = 14.288984523457062
# ndf = 17
# Fitted values:
# [ 1.09082004  0.99633018 43.50916453]
# Errors:
# [0.52698002 0.07024976 0.13804423]
# Covariance:
# [[ 0.27770794 -0.02527797 -0.04227843]
#  [-0.02527797  0.00493503  0.00942366]
#  [-0.04227843  0.00942366  0.01905621]]
# SN-36: μ = 43.509 ± 0.138, s = 0.996 ± 0.070
#
# Fitting SN-37...
# Fitting with Minuit
# Chi2 = 27.690977590063223
# ndf = 17
# Fitted values:
# [ 0.40317468  0.88503622 42.80135696]
# Errors:
# [0.46172649 0.04834207 0.10593329]
# Covariance:
# [[ 0.21319135 -0.01528338 -0.02618785]
#  [-0.01528338  0.00233696  0.00486919]
#  [-0.02618785  0.00486919  0.01122186]]
# SN-37: μ = 42.801 ± 0.106, s = 0.885 ± 0.048
#
# Fitting SN-38...
# Fitting with Minuit
# Chi2 = 18.690420290476826
# ndf = 17
# Fitted values:
# [1.55585898e-02 1.17675304e+00 4.37841239e+01]
# Errors:
# [0.86018862 0.11134595 0.19292899]
# Covariance:
# [[ 0.73992447 -0.07524469 -0.11733812]
#  [-0.07524469  0.01239792  0.02112576]
#  [-0.11733812  0.02112576  0.0372216 ]]
# SN-38: μ = 43.784 ± 0.193, s = 1.177 ± 0.111
#
# Fitting SN-39...
# Fitting with Minuit
# Chi2 = 17.40423025684918
# ndf = 17
# Fitted values:
# [-3.51306823  0.92882871 42.74090425]
# Errors:
# [0.7818493  0.05259714 0.10034104]
# Covariance:
# [[ 0.61128833 -0.03219589 -0.03511004]
#  [-0.03219589  0.00276646  0.00463293]
#  [-0.03511004  0.00463293  0.01006833]]
# SN-39: μ = 42.741 ± 0.100, s = 0.929 ± 0.053
#
# Fitting SN-40...
# Fitting with Minuit
# Chi2 = 9.03542840105808
# ndf = 17
# Fitted values:
# [-1.18887387  1.0121286  43.11887076]
# Errors:
# [0.75535084 0.06749532 0.12308035]
# Covariance:
# [[ 0.57055489 -0.0407197  -0.05775451]
#  [-0.0407197   0.00455562  0.00786803]
#  [-0.05775451  0.00786803  0.01514877]]
# SN-40: μ = 43.119 ± 0.123, s = 1.012 ± 0.067
#
# Fitting SN-41...
# Fitting with Minuit
# Chi2 = 11.055763561372455
# ndf = 17
# Fitted values:
# [ 0.06267665  0.99260245 42.14154201]
# Errors:
# [0.51210222 0.05341244 0.11388544]
# Covariance:
# [[ 0.26224868 -0.01897838 -0.03217723]
#  [-0.01897838  0.00285289  0.00582742]
#  [-0.03217723  0.00582742  0.01296989]]
# SN-41: μ = 42.142 ± 0.114, s = 0.993 ± 0.053
#
# Fitting SN-42...
# Fitting with Minuit
# Chi2 = 16.71291354719023
# ndf = 17
# Fitted values:
# [-1.3152903   1.01983029 43.80930676]
# Errors:
# [0.0739796  0.01387733 0.04218396]
# Covariance:
# [[ 5.47298085e-03 -3.49827931e-05  2.26669097e-04]
#  [-3.49827931e-05  1.92580372e-04  4.10145889e-04]
#  [ 2.26669097e-04  4.10145889e-04  1.77948608e-03]]
# SN-42: μ = 43.809 ± 0.042, s = 1.020 ± 0.014
#
# Fitting SN-43...
# Fitting with Minuit
# Chi2 = 8.482882002167194
# ndf = 17
# Fitted values:
# [ 1.1787098   1.10585653 43.33900052]
# Errors:
# [0.59958478 0.07868897 0.14846411]
# Covariance:
# [[ 0.35950191 -0.0335431  -0.05583654]
#  [-0.0335431   0.00619195  0.01141927]
#  [-0.05583654  0.01141927  0.02204159]]
# SN-43: μ = 43.339 ± 0.148, s = 1.106 ± 0.079
#
# Fitting SN-44...
# Fitting with Minuit
# Chi2 = 8.86190855708126
# ndf = 17
# Fitted values:
# [-0.75810854  1.03685543 43.93371324]
# Errors:
# [0.86598393 0.09720086 0.16801688]
# Covariance:
# [[ 0.74992817 -0.06912257 -0.10388421]
#  [-0.06912257  0.00944801  0.01588746]
#  [-0.10388421  0.01588746  0.02822967]]
# SN-44: μ = 43.934 ± 0.168, s = 1.037 ± 0.097
#
# Fitting SN-45...
# Fitting with Minuit
# Chi2 = 9.91689112872506
# ndf = 17
# Fitted values:
# [ 1.30392225  1.0166227  41.62962729]
# Errors:
# [0.36320423 0.04364118 0.10196866]
# Covariance:
# [[ 0.13191732 -0.00846882 -0.01532158]
#  [-0.00846882  0.00190455  0.00425866]
#  [-0.01532158  0.00425866  0.01039761]]
# SN-45: μ = 41.630 ± 0.102, s = 1.017 ± 0.044
#
# Fitting SN-46...
# Fitting with Minuit
# Chi2 = 14.436558526284927
# ndf = 17
# Fitted values:
# [ 2.04911136  0.93879494 42.75966563]
# Errors:
# [0.12378851 0.01836242 0.052322  ]
# Covariance:
# [[0.0153236  0.00198353 0.00488716]
#  [0.00198353 0.00033718 0.00081471]
#  [0.00488716 0.00081471 0.00273759]]
# SN-46: μ = 42.760 ± 0.052, s = 0.939 ± 0.018
#
# Fitting SN-47...
# Fitting with Minuit
# Chi2 = 13.752589532793985
# ndf = 17
# Fitted values:
# [-1.84845318  1.01155956 42.12768851]
# Errors:
# [0.04350005 0.01078384 0.03832698]
# Covariance:
# [[ 1.89225405e-03 -1.15164837e-05  9.02551554e-05]
#  [-1.15164837e-05  1.16291189e-04  2.87300828e-04]
#  [ 9.02551554e-05  2.87300828e-04  1.46895715e-03]]
# SN-47: μ = 42.128 ± 0.038, s = 1.012 ± 0.011
#
# Fitting SN-48...
# Fitting with Minuit
# Chi2 = 13.30688180182203
# ndf = 17
# Fitted values:
# [-1.74122196  1.10456091 43.78065155]
# Errors:
# [1.09039251 0.10181488 0.16637582]
# Covariance:
# [[ 1.18895583 -0.0947217  -0.13184987]
#  [-0.0947217   0.01036627  0.01637273]
#  [-0.13184987  0.01637273  0.02768091]]
# SN-48: μ = 43.781 ± 0.166, s = 1.105 ± 0.102
#
# Fitting SN-49...
# Fitting with Minuit
# Chi2 = 19.91920551885849
# ndf = 17
# Fitted values:
# [-3.52381669  1.20851693 43.76438395]
# Errors:
# [1.55851044 0.12575805 0.18805391]
# Covariance:
# [[ 2.4289548  -0.17442537 -0.22091187]
#  [-0.17442537  0.01581509  0.02275597]
#  [-0.22091187  0.02275597  0.03536427]]
# SN-49: μ = 43.764 ± 0.188, s = 1.209 ± 0.126
#
# Fitting SN-50...
# Fitting with Minuit
# Chi2 = 15.891735856654167
# ndf = 17
# Fitted values:
# [-1.58274081  1.09695114 43.69438896]
# Errors:
# [0.9069011  0.09316514 0.1607265 ]
# Covariance:
# [[ 0.8224696  -0.06947876 -0.10212118]
#  [-0.06947876  0.00867974  0.01451068]
#  [-0.10212118  0.01451068  0.02583301]]
# SN-50: μ = 43.694 ± 0.161, s = 1.097 ± 0.093
#
# Fitting SN-51...
# Fitting with Minuit
# Chi2 = 13.31059018723621
# ndf = 17
# Fitted values:
# [ 2.08630327  1.03483774 42.87379193]
# Errors:
# [0.37213669 0.05776624 0.12204461]
# Covariance:
# [[ 0.13848571 -0.00815788 -0.0137224 ]
#  [-0.00815788  0.00333694  0.00684919]
#  [-0.0137224   0.00684919  0.01489489]]
# SN-51: μ = 42.874 ± 0.122, s = 1.035 ± 0.058
#
# Fitting SN-52...
# Fitting with Minuit
# Chi2 = 12.445454501823775
# ndf = 17
# Fitted values:
# [ 2.1313899   0.89130153 43.13458768]
# Errors:
# [0.08020368 0.01053336 0.03817805]
# Covariance:
# [[0.00643263 0.00072142 0.00178665]
#  [0.00072142 0.00011095 0.0002694 ]
#  [0.00178665 0.0002694  0.00145756]]
# SN-52: μ = 43.135 ± 0.038, s = 0.891 ± 0.011
#
# Fitting SN-53...
# Fitting with Minuit
# Chi2 = 17.612117543513087
# ndf = 17
# Fitted values:
# [ 0.0436503   0.96674247 43.03075429]
# Errors:
# [0.10528724 0.02482661 0.06539257]
# Covariance:
# [[0.0110854  0.00100962 0.00286299]
#  [0.00100962 0.00061636 0.00146001]
#  [0.00286299 0.00146001 0.00427619]]
# SN-53: μ = 43.031 ± 0.065, s = 0.967 ± 0.025
#
# Fitting SN-54...
# Fitting with Minuit
# Chi2 = 12.778743131059798
# ndf = 17
# Fitted values:
# [ 2.33198155  0.9940848  42.30507828]
# Errors:
# [0.26540645 0.03855605 0.0940422 ]
# Covariance:
# [[ 0.07044058 -0.00027133  0.00084529]
#  [-0.00027133  0.00148657  0.00346282]
#  [ 0.00084529  0.00346282  0.00884394]]
# SN-54: μ = 42.305 ± 0.094, s = 0.994 ± 0.039
#
# Fitting SN-55...
# Fitting with Minuit
# Chi2 = 8.318816811855152
# ndf = 17
# Fitted values:
# [-0.94830981  0.92397185 43.7278888 ]
# Errors:
# [0.72293352 0.07144247 0.13070898]
# Covariance:
# [[ 0.52263287 -0.0407233  -0.05862557]
#  [-0.0407233   0.00510403  0.0088692 ]
#  [-0.05862557  0.0088692   0.01708484]]
# SN-55: μ = 43.728 ± 0.131, s = 0.924 ± 0.071
#
# Fitting SN-56...
# Fitting with Minuit
# Chi2 = 18.143680888953877
# ndf = 17
# Fitted values:
# [ 1.24683782  0.94384331 43.02683693]
# Errors:
# [0.3642348  0.04927934 0.10849358]
# Covariance:
# [[ 0.13266699 -0.00789379 -0.01264796]
#  [-0.00789379  0.00242845  0.0051293 ]
#  [-0.01264796  0.0051293   0.01177086]]
# SN-56: μ = 43.027 ± 0.108, s = 0.944 ± 0.049
#
# Fitting SN-57...
# Fitting with Minuit
# Chi2 = 15.987145415751257
# ndf = 17
# Fitted values:
# [ 1.76307755  1.20568877 42.68890276]
# Errors:
# [0.63388988 0.08264351 0.15442358]
# Covariance:
# [[ 0.40181638 -0.03714728 -0.061681  ]
#  [-0.03714728  0.00682995  0.01250682]
#  [-0.061681    0.01250682  0.02384664]]
# SN-57: μ = 42.689 ± 0.154, s = 1.206 ± 0.083
#
# Fitting SN-58...
# Fitting with Minuit
# Chi2 = 12.449021382632269
# ndf = 17
# Fitted values:
# [ 2.12368043  1.00654174 42.19113792]
# Errors:
# [0.26133833 0.03742005 0.09286892]
# Covariance:
# [[ 0.06829772 -0.00101977 -0.00063034]
#  [-0.00101977  0.00140026  0.00331192]
#  [-0.00063034  0.00331192  0.00862464]]
# SN-58: μ = 42.191 ± 0.093, s = 1.007 ± 0.037
#
# Fitting SN-59...
# Fitting with Minuit
# Chi2 = 12.759106845286821
# ndf = 17
# Fitted values:
# [-0.60568722  0.88452453 43.71866789]
# Errors:
# [0.58029463 0.06388255 0.12675495]
# Covariance:
# [[ 0.33674185 -0.02804397 -0.04558681]
#  [-0.02804397  0.00408098  0.0077479 ]
#  [-0.04558681  0.0077479   0.01606682]]
# SN-59: μ = 43.719 ± 0.127, s = 0.885 ± 0.064
#
# Fitting SN-60...
# Fitting with Minuit
# Chi2 = 12.479426589572144
# ndf = 17
# Fitted values:
# [-1.94127813  1.17177708 44.00706977]
# Errors:
# [1.19662473 0.11437059 0.18346468]
# Covariance:
# [[ 1.43191073 -0.11680759 -0.16203805]
#  [-0.11680759  0.01308063  0.02038533]
#  [-0.16203805  0.02038533  0.03365929]]
# SN-60: μ = 44.007 ± 0.183, s = 1.172 ± 0.114
#
# Fitting SN-61...
# Fitting with Minuit
# Chi2 = 22.32260403048731
# ndf = 17
# Fitted values:
# [-2.17726887  1.05747052 43.11646683]
# Errors:
# [0.80453239 0.06975596 0.12697837]
# Covariance:
# [[ 0.64727236 -0.04407132 -0.06193815]
#  [-0.04407132  0.00486589  0.00840472]
#  [-0.06193815  0.00840472  0.01612351]]
# SN-61: μ = 43.116 ± 0.127, s = 1.057 ± 0.070
#
# Fitting SN-62...
# Fitting with Minuit
# Chi2 = 19.160737472138063
# ndf = 17
# Fitted values:
# [ 1.44960579  0.98961519 43.05105208]
# Errors:
# [0.36889966 0.05230204 0.11341286]
# Covariance:
# [[ 0.13608696 -0.00940979 -0.01598686]
#  [-0.00940979  0.0027355   0.00571856]
#  [-0.01598686  0.00571856  0.01286248]]
# SN-62: μ = 43.051 ± 0.113, s = 0.990 ± 0.052
#
# Fitting SN-63...
# Fitting with Minuit
# Chi2 = 16.435986570243365
# ndf = 17
# Fitted values:
# [ 0.63452355  1.01943512 41.55353682]
# Errors:
# [0.39111049 0.04438747 0.1022173 ]
# Covariance:
# [[ 0.15296742 -0.00873285 -0.01447472]
#  [-0.00873285  0.00197025  0.00433029]
#  [-0.01447472  0.00433029  0.01044838]]
# SN-63: μ = 41.554 ± 0.102, s = 1.019 ± 0.044
#
# Fitting SN-64...
# Fitting with Minuit
# Chi2 = 18.925412759492325
# ndf = 17
# Fitted values:
# [ 0.53925943  1.0088761  43.45331295]
# Errors:
# [0.60227187 0.07385129 0.1417271 ]
# Covariance:
# [[ 0.36273141 -0.03330956 -0.05549844]
#  [-0.03330956  0.00545401  0.01017901]
#  [-0.05549844  0.01017901  0.02008657]]
# SN-64: μ = 43.453 ± 0.142, s = 1.009 ± 0.074
#
# Fitting SN-65...
# Fitting with Minuit
# Chi2 = 12.556938468238016
# ndf = 17
# Fitted values:
# [-1.52253732  0.8860016  41.98384176]
# Errors:
# [0.51072099 0.04003119 0.09119114]
# Covariance:
# [[ 0.26083593 -0.01441158 -0.02099308]
#  [-0.01441158  0.0016025   0.00333448]
#  [-0.02099308  0.00333448  0.00831582]]
# SN-65: μ = 41.984 ± 0.091, s = 0.886 ± 0.040
#
# Fitting SN-66...
# Fitting with Minuit
# Chi2 = 14.086960710281785
# ndf = 17
# Fitted values:
# [-0.59870883  1.08405486 43.66433107]
# Errors:
# [0.87083632 0.09368074 0.16186025]
# Covariance:
# [[ 0.75835589 -0.06691609 -0.09987721]
#  [-0.06691609  0.00877608  0.01473698]
#  [-0.09987721  0.01473698  0.02619874]]
# SN-66: μ = 43.664 ± 0.162, s = 1.084 ± 0.094
#
# Fitting SN-67...
# Fitting with Minuit
# Chi2 = 18.863487570622194
# ndf = 17
# Fitted values:
# [-0.24629089  1.20669542 43.86254059]
# Errors:
# [0.90881095 0.11068862 0.19035589]
# Covariance:
# [[ 0.82593735 -0.08250177 -0.12868634]
#  [-0.08250177  0.01225197  0.02070731]
#  [-0.12868634  0.02070731  0.03623536]]
# SN-67: μ = 43.863 ± 0.190, s = 1.207 ± 0.111
#
# Fitting SN-68...
# Fitting with Minuit
# Chi2 = 16.2427747742689
# ndf = 17
# Fitted values:
# [ 1.55186654  0.95287346 42.62449038]
# Errors:
# [0.34480273 0.04556663 0.10467184]
# Covariance:
# [[ 0.11888892 -0.00686676 -0.01190879]
#  [-0.00686676  0.00207632  0.00457644]
#  [-0.01190879  0.00457644  0.0109562 ]]
# SN-68: μ = 42.624 ± 0.105, s = 0.953 ± 0.046
#
# Fitting SN-69...
# Fitting with Minuit
# Chi2 = 24.32749328326801
# ndf = 17
# Fitted values:
# [ 0.77517882  1.08544404 42.58231179]
# Errors:
# [3.58812778 0.07409113 0.01547454]
# Covariance:
# [[ 1.28746610e+01 -2.65485464e-01 -1.45396360e-02]
#  [-2.65485464e-01  5.48949534e-03  3.09054636e-04]
#  [-1.45396360e-02  3.09054636e-04  2.39461249e-04]]
# SN-69: μ = 42.582 ± 0.015, s = 1.085 ± 0.074
#
# Fitting SN-70...
# Fitting with Minuit
# Chi2 = 13.56363616975217
# ndf = 17
# Fitted values:
# [ 1.8877571   1.08921301 44.45855582]
# Errors:
# [0.6177766  0.10856342 0.19728343]
# Covariance:
# [[ 0.38164793 -0.04065305 -0.06770257]
#  [-0.04065305  0.01178602  0.02112212]
#  [-0.06770257  0.02112212  0.03892075]]
# SN-70: μ = 44.459 ± 0.197, s = 1.089 ± 0.109
#
# Fitting SN-71...
# Fitting with Minuit
# Chi2 = 21.755167894398028
# ndf = 17
# Fitted values:
# [ 1.94098055  0.99146395 43.54034942]
# Errors:
# [0.36432372 0.05730449 0.12080337]
# Covariance:
# [[ 0.13273178 -0.00867109 -0.01472285]
#  [-0.00867109  0.0032838   0.00670621]
#  [-0.01472285  0.00670621  0.01459345]]
# SN-71: μ = 43.540 ± 0.121, s = 0.991 ± 0.057
#
# Fitting SN-72...
# Fitting with Minuit
# Chi2 = 17.722122128459525
# ndf = 17
# Fitted values:
# [ 2.76295924  0.89975781 41.95463626]
# Errors:
# [0.20017037 0.02774186 0.08036988]
# Covariance:
# [[0.04006818 0.00149773 0.00445799]
#  [0.00149773 0.00076961 0.00209627]
#  [0.00445799 0.00209627 0.00645932]]
# SN-72: μ = 41.955 ± 0.080, s = 0.900 ± 0.028
#
# Fitting SN-73...
# Fitting with Minuit
# Chi2 = 11.883595764088062
# ndf = 17
# Fitted values:
# [-1.33506733  1.10933234 43.38728134]
# Errors:
# [0.84784566 0.0830099  0.14678044]
# Covariance:
# [[ 0.71884226 -0.05487576 -0.07879473]
#  [-0.05487576  0.00689064  0.01173425]
#  [-0.07879473  0.01173425  0.0215445 ]]
# SN-73: μ = 43.387 ± 0.147, s = 1.109 ± 0.083
#
# Fitting SN-74...
# Fitting with Minuit
# Chi2 = 16.306891561637183
# ndf = 17
# Fitted values:
# [-1.43468549  0.92817474 42.51959358]
# Errors:
# [0.55115668 0.05037601 0.10753248]
# Covariance:
# [[ 0.30377369 -0.02070616 -0.03306013]
#  [-0.02070616  0.00253774  0.00509865]
#  [-0.03306013  0.00509865  0.01156323]]
# SN-74: μ = 42.520 ± 0.108, s = 0.928 ± 0.050
#
# Fitting SN-75...
# Fitting with Minuit
# Chi2 = 7.293187617181584
# ndf = 17
# Fitted values:
# [-0.40518642  1.08433574 44.01948351]
# Errors:
# [0.52354494 0.0114801  0.04094599]
# Covariance:
# [[ 2.74099303e-01 -8.53875603e-04  8.83573760e-03]
#  [-8.53875603e-04  1.31792655e-04  2.27901836e-04]
#  [ 8.83573760e-03  2.27901836e-04  1.67657369e-03]]
# SN-75: μ = 44.019 ± 0.041, s = 1.084 ± 0.011
#
# Fitting SN-76...
# Fitting with Minuit
# Chi2 = 13.441291912057443
# ndf = 17
# Fitted values:
# [ 1.53371807  0.90519154 44.10891779]
# Errors:
# [0.50476119 0.07922415 0.15623441]
# Covariance:
# [[ 0.25478386 -0.02454168 -0.04271724]
#  [-0.02454168  0.00627647  0.01209108]
#  [-0.04271724  0.01209108  0.02440919]]
# SN-76: μ = 44.109 ± 0.156, s = 0.905 ± 0.079
#
# Fitting SN-77...
# Fitting with Minuit
# Chi2 = 14.514574933040889
# ndf = 17
# Fitted values:
# [ 1.83892998  1.08839038 42.7840215 ]
# Errors:
# [0.39833109 0.06161227 0.12749131]
# Covariance:
# [[ 0.15866766 -0.01003751 -0.01709859]
#  [-0.01003751  0.00379607  0.00765279]
#  [-0.01709859  0.00765279  0.01625403]]
# SN-77: μ = 42.784 ± 0.127, s = 1.088 ± 0.062
#
# Fitting SN-78...
# Fitting with Minuit
# Chi2 = 16.0725961680064
# ndf = 17
# Fitted values:
# [ 0.12220612  1.15027298 44.59465097]
# Errors:
# [0.98084688 0.13168156 0.22193443]
# Covariance:
# [[ 0.96206061 -0.10409412 -0.1619379 ]
#  [-0.10409412  0.01734003  0.02882099]
#  [-0.1619379   0.02882099  0.04925489]]
# SN-78: μ = 44.595 ± 0.222, s = 1.150 ± 0.132
#
# Fitting SN-79...
# Fitting with Minuit
# Chi2 = 14.523173459657905
# ndf = 17
# Fitted values:
# [ 1.18503294  1.16305006 43.86368767]
# Errors:
# [0.10635807 0.0186775  0.0455368 ]
# Covariance:
# [[ 1.13120385e-02 -7.55661892e-05  1.89533605e-04]
#  [-7.55661892e-05  3.48848993e-04  6.61520425e-04]
#  [ 1.89533605e-04  6.61520425e-04  2.07359980e-03]]
# SN-79: μ = 43.864 ± 0.046, s = 1.163 ± 0.019
#
# Fitting SN-80...
# Fitting with Minuit
# Chi2 = 7.67191677169081
# ndf = 17
# Fitted values:
# [-2.54281739  0.89890139 43.66000242]
# Errors:
# [0.86811458 0.06930096 0.12204559]
# Covariance:
# [[ 0.75362293 -0.04879101 -0.06163756]
#  [-0.04879101  0.00480262  0.00781139]
#  [-0.06163756  0.00781139  0.01489513]]
# SN-80: μ = 43.660 ± 0.122, s = 0.899 ± 0.069
#
# Fitting SN-81...
# Fitting with Minuit
# Chi2 = 14.000933254448837
# ndf = 17
# Fitted values:
# [-1.23947635  1.11417677 44.09829989]
# Errors:
# [1.18504428 0.12058794 0.19321637]
# Covariance:
# [[ 1.40432994 -0.12425992 -0.17705553]
#  [-0.12425992  0.01454145  0.02274226]
#  [-0.17705553  0.02274226  0.03733257]]
# SN-81: μ = 44.098 ± 0.193, s = 1.114 ± 0.121
#
# Fitting SN-82...
# Fitting with Minuit
# Chi2 = 8.780825969975014
# ndf = 17
# Fitted values:
# [-1.85799306  0.99701629 43.44829411]
# Errors:
# [0.23873641 0.04661359 0.10430387]
# Covariance:
# [[ 0.05699508 -0.0040961  -0.00593482]
#  [-0.0040961   0.00217283  0.00463138]
#  [-0.00593482  0.00463138  0.0108793 ]]
# SN-82: μ = 43.448 ± 0.104, s = 0.997 ± 0.047
#
# Fitting SN-83...
# Fitting with Minuit
# Chi2 = 10.216901270791327
# ndf = 17
# Fitted values:
# [-3.01157117  1.15169542 43.37623389]
# Errors:
# [0.0779216  0.02103421 0.05628053]
# Covariance:
# [[0.00607178 0.00094584 0.00242481]
#  [0.00094584 0.00044244 0.00102049]
#  [0.00242481 0.00102049 0.0031675 ]]
# SN-83: μ = 43.376 ± 0.056, s = 1.152 ± 0.021
#
# Fitting SN-84...
# Fitting with Minuit
# Chi2 = 26.15056292244603
# ndf = 17
# Fitted values:
# [-1.11664912  0.99828154 42.80663404]
# Errors:
# [0.60421873 0.05692747 0.11375314]
# Covariance:
# [[ 0.36508027 -0.02525532 -0.03842103]
#  [-0.02525532  0.00324074  0.00614021]
#  [-0.03842103  0.00614021  0.01293978]]
# SN-84: μ = 42.807 ± 0.114, s = 0.998 ± 0.057
#
# Fitting SN-85...
# Fitting with Minuit
# Chi2 = 28.64979703927628
# ndf = 17
# Fitted values:
# [-3.30395478  1.10517969 43.06825807]
# Errors:
# [0.06975125 0.02218295 0.06075266]
# Covariance:
# [[0.00486524 0.00107097 0.00275895]
#  [0.00107097 0.00049208 0.0011933 ]
#  [0.00275895 0.0011933  0.00369089]]
# SN-85: μ = 43.068 ± 0.061, s = 1.105 ± 0.022
#
# Fitting SN-86...
# Fitting with Minuit
# Chi2 = 15.732297109837429
# ndf = 17
# Fitted values:
# [-2.88163388  0.93822174 43.54622269]
# Errors:
# [0.54097371 0.01251959 0.05044987]
# Covariance:
# [[ 2.92652555e-01 -1.63941555e-03  1.54925776e-02]
#  [-1.63941555e-03  1.56740114e-04  2.55345276e-04]
#  [ 1.54925776e-02  2.55345276e-04  2.54518914e-03]]
# SN-86: μ = 43.546 ± 0.050, s = 0.938 ± 0.013
#
# Fitting SN-87...
# Fitting with Minuit
# Chi2 = 21.508649341993777
# ndf = 17
# Fitted values:
# [ 2.37577599  1.01490651 43.50223761]
# Errors:
# [0.37718525 0.06077302 0.12510401]
# Covariance:
# [[ 0.14226872 -0.00765147 -0.01269669]
#  [-0.00765147  0.00369336  0.00739149]
#  [-0.01269669  0.00739149  0.01565101]]
# SN-87: μ = 43.502 ± 0.125, s = 1.015 ± 0.061
#
# Fitting SN-88...
# Fitting with Minuit
# Chi2 = 12.526548953873833
# ndf = 17
# Fitted values:
# [ 2.01261319  1.08739729 42.19638882]
# Errors:
# [0.38181169 0.05619919 0.12069723]
# Covariance:
# [[ 0.14578017 -0.00862543 -0.01439031]
#  [-0.00862543  0.00315835  0.00658342]
#  [-0.01439031  0.00658342  0.01456782]]
# SN-88: μ = 42.196 ± 0.121, s = 1.087 ± 0.056
#
# Fitting SN-89...
# Fitting with Minuit
# Chi2 = 5.910588784463942
# ndf = 17
# Fitted values:
# [ 1.85559058  1.01488453 43.64788792]
# Errors:
# [0.51471179 0.07952227 0.1541459 ]
# Covariance:
# [[ 0.26492822 -0.02557727 -0.04377959]
#  [-0.02557727  0.00632379  0.01200778]
#  [-0.04377959  0.01200778  0.02376096]]
# SN-89: μ = 43.648 ± 0.154, s = 1.015 ± 0.080
#
# Fitting SN-90...
# Fitting with Minuit
# Chi2 = 16.49115595683413
# ndf = 17
# Fitted values:
# [ 1.38348493  0.90717361 43.240762  ]
# Errors:
# [0.33593524 0.04871864 0.11018677]
# Covariance:
# [[ 0.11285249 -0.00688302 -0.01191492]
#  [-0.00688302  0.00237351  0.0051618 ]
#  [-0.01191492  0.0051618   0.01214112]]
# SN-90: μ = 43.241 ± 0.110, s = 0.907 ± 0.049
#
# Fitting SN-91...
# Fitting with Minuit
# Chi2 = 8.086728207483253
# ndf = 17
# Fitted values:
# [ 2.34593276  0.95713843 43.50642262]
# Errors:
# [0.34852228 0.05232605 0.11335874]
# Covariance:
# [[ 0.12146778 -0.00699466 -0.01165333]
#  [-0.00699466  0.00273802  0.00571846]
#  [-0.01165333  0.00571846  0.0128502 ]]
# SN-91: μ = 43.506 ± 0.113, s = 0.957 ± 0.052
#
# Fitting SN-92...
# Fitting with Minuit
# Chi2 = 23.794688361961825
# ndf = 17
# Fitted values:
# [-0.23751808  0.99590996 42.07337027]
# Errors:
# [0.53595166 0.05216566 0.11004667]
# Covariance:
# [[ 0.28724418 -0.02013697 -0.03290424]
#  [-0.02013697  0.00272126  0.00546003]
#  [-0.03290424  0.00546003  0.01211027]]
# SN-92: μ = 42.073 ± 0.110, s = 0.996 ± 0.052
#
# Fitting SN-93...
# Fitting with Minuit
# Chi2 = 17.878447425319234
# ndf = 17
# Fitted values:
# [-0.21691735  1.11022657 43.10008501]
# Errors:
# [0.68005114 0.07988261 0.14840698]
# Covariance:
# [[ 0.46246955 -0.03944847 -0.0616644 ]
#  [-0.03944847  0.00638123  0.01152977]
#  [-0.0616644   0.01152977  0.02202463]]
# SN-93: μ = 43.100 ± 0.148, s = 1.110 ± 0.080
#
# Fitting SN-94...
# Fitting with Minuit
# Chi2 = 21.8347558654093
# ndf = 17
# Fitted values:
# [-1.89123668  1.18466929 42.83179244]
# Errors:
# [4.22260212 0.10057478 0.01822175]
# Covariance:
# [[ 1.78303686e+01 -4.23989802e-01  1.54612837e-02]
#  [-4.23989802e-01  1.01152855e-02 -3.40220825e-04]
#  [ 1.54612837e-02 -3.40220825e-04  3.32032220e-04]]
# SN-94: μ = 42.832 ± 0.018, s = 1.185 ± 0.101
#
# Fitting SN-95...
# Fitting with Minuit
# Chi2 = 10.98836627277323
# ndf = 17
# Fitted values:
# [3.11005407e-02 9.72852364e-01 4.29522421e+01]
# Errors:
# [0.58285148 0.05999472 0.11856193]
# Covariance:
# [[ 0.33971585 -0.02521387 -0.03926938]
#  [-0.02521387  0.00359937  0.00679976]
#  [-0.03926938  0.00679976  0.01405693]]
# SN-95: μ = 42.952 ± 0.119, s = 0.973 ± 0.060
#
# Fitting SN-96...
# Fitting with Minuit
# Chi2 = 29.18007063148911
# ndf = 17
# Fitted values:
# [ 0.36314317  1.0346474  42.99406465]
# Errors:
# [0.60030835 0.07074508 0.13754769]
# Covariance:
# [[ 0.36037011 -0.03224925 -0.0542015 ]
#  [-0.03224925  0.00500487  0.00945237]
#  [-0.0542015   0.00945237  0.01891937]]
# SN-96: μ = 42.994 ± 0.138, s = 1.035 ± 0.071
#
# Fitting SN-97...
# Fitting with Minuit
# Chi2 = 13.863649110549844
# ndf = 17
# Fitted values:
# [-0.66088045  1.00305806 44.17327533]
# Errors:
# [0.8821108  0.09868197 0.17061729]
# Covariance:
# [[ 0.77811946 -0.07132097 -0.10698681]
#  [-0.07132097  0.00973813  0.01636043]
#  [-0.10698681  0.01636043  0.02911026]]
# SN-97: μ = 44.173 ± 0.171, s = 1.003 ± 0.099
#
# Fitting SN-98...
# Fitting with Minuit
# Chi2 = 13.713321876507287
# ndf = 17
# Fitted values:
# [ 3.20274409  1.07260245 42.16495931]
# Errors:
# [0.28160482 0.04429013 0.10245073]
# Covariance:
# [[0.07930127 0.00077005 0.00278856]
#  [0.00077005 0.00196162 0.00437164]
#  [0.00278856 0.00437164 0.01049615]]
# SN-98: μ = 42.165 ± 0.102, s = 1.073 ± 0.044
#
# Fitting SN-99...
# Fitting with Minuit
# Chi2 = 8.853094153422258
# ndf = 17
# Fitted values:
# [ 1.48066649  0.97962084 42.70120832]
# Errors:
# [0.353541   0.05005855 0.11144708]
# Covariance:
# [[ 0.12499124 -0.00774981 -0.01332467]
#  [-0.00774981  0.00250586  0.00538   ]
#  [-0.01332467  0.00538     0.01242045]]
# SN-99: μ = 42.701 ± 0.111, s = 0.980 ± 0.050
#
# Fitting SN-100...
# Fitting with Minuit
# Chi2 = 9.221877511545724
# ndf = 17
# Fitted values:
# [ 2.31754661  1.0228414  42.62147042]
# Errors:
# [0.36163812 0.05097279 0.11098965]
# Covariance:
# [[ 0.13078213 -0.00796891 -0.01368184]
#  [-0.00796891  0.00259822  0.00546106]
#  [-0.01368184  0.00546106  0.0123187 ]]
# SN-100: μ = 42.621 ± 0.111, s = 1.023 ± 0.051
#
# Fitting SN-101...
# Fitting with Minuit
# Chi2 = 22.078043312488628
# ndf = 17
# Fitted values:
# [ 1.93048971  1.01394851 42.91868561]
# Errors:
# [0.36317222 0.0520194  0.1132397 ]
# Covariance:
# [[ 0.13189406 -0.00877247 -0.01532318]
#  [-0.00877247  0.00270602  0.00568965]
#  [-0.01532318  0.00568965  0.01282323]]
# SN-101: μ = 42.919 ± 0.113, s = 1.014 ± 0.052
#
# Fitting SN-102...
# Fitting with Minuit
# Chi2 = 12.534198718096745
# ndf = 17
# Fitted values:
# [-2.30697427  0.98805202 41.6915605 ]
# Errors:
# [0.7024406  0.04868719 0.0983933 ]
# Covariance:
# [[ 0.4934228  -0.02605285 -0.03432049]
#  [-0.02605285  0.00237044  0.00436464]
#  [-0.03432049  0.00436464  0.00968124]]
# SN-102: μ = 41.692 ± 0.098, s = 0.988 ± 0.049
#
# Fitting SN-103...
# Fitting with Minuit
# Chi2 = 17.538081505384568
# ndf = 17
# Fitted values:
# [-3.43992964  1.19766367 42.80367196]
# Errors:
# [0.16151087 0.05947404 0.14108057]
# Covariance:
# [[0.02608576 0.00616398 0.01523117]
#  [0.00616398 0.00353716 0.00821767]
#  [0.01523117 0.00821767 0.01990373]]
# SN-103: μ = 42.804 ± 0.141, s = 1.198 ± 0.059
#
# Fitting SN-104...
# Fitting with Minuit
# Chi2 = 8.203652166912876
# ndf = 17
# Fitted values:
# [ 3.43791492  0.9826282  42.58937722]
# Errors:
# [0.25326568 0.03914296 0.09501636]
# Covariance:
# [[0.06414351 0.00156726 0.0041042 ]
#  [0.00156726 0.00153217 0.00355997]
#  [0.0041042  0.00355997 0.00902811]]
# SN-104: μ = 42.589 ± 0.095, s = 0.983 ± 0.039
#
# Fitting SN-105...
# Fitting with Minuit
# Chi2 = 7.003476857954573
# ndf = 17
# Fitted values:
# [-3.18273105  1.02740094 43.40118613]
# Errors:
# [0.95687503 0.07297072 0.12597284]
# Covariance:
# [[ 0.91560982 -0.05725074 -0.07289574]
#  [-0.05725074  0.00532473  0.00856822]
#  [-0.07289574  0.00856822  0.01586916]]
# SN-105: μ = 43.401 ± 0.126, s = 1.027 ± 0.073
#
# Fitting SN-106...
# Fitting with Minuit
# Chi2 = 17.853341601248584
# ndf = 17
# Fitted values:
# [ 1.95820167  0.8913612  42.78749575]
# Errors:
# [0.23595141 0.03475926 0.08989597]
# Covariance:
# [[ 0.05567307 -0.00059618  0.00012261]
#  [-0.00059618  0.00120821  0.00296164]
#  [ 0.00012261  0.00296164  0.00808128]]
# SN-106: μ = 42.787 ± 0.090, s = 0.891 ± 0.035
#
# Fitting SN-107...
# Fitting with Minuit
# Chi2 = 10.805905953044189
# ndf = 17
# Fitted values:
# [-2.21822671  0.94694165 44.31427453]
# Errors:
# [0.10042226 0.0219095  0.05756043]
# Covariance:
# [[ 0.01008463 -0.00013255  0.00029993]
#  [-0.00013255  0.00048003  0.00100409]
#  [ 0.00029993  0.00100409  0.0033132 ]]
# SN-107: μ = 44.314 ± 0.058, s = 0.947 ± 0.022
#
# Fitting SN-108...
# Fitting with Minuit
# Chi2 = 11.54367066764656
# ndf = 17
# Fitted values:
# [ 2.43974991  0.94678277 43.66875872]
# Errors:
# [0.06488563 0.02182406 0.05425476]
# Covariance:
# [[0.00421015 0.00079089 0.00171252]
#  [0.00079089 0.00047629 0.00100063]
#  [0.00171252 0.00100063 0.00294358]]
# SN-108: μ = 43.669 ± 0.054, s = 0.947 ± 0.022
#
# Fitting SN-109...
# Fitting with Minuit
# Chi2 = 16.960847382688524
# ndf = 17
# Fitted values:
# [ 2.80564756  0.92890332 41.75170869]
# Errors:
# [0.20537341 0.02852229 0.08144017]
# Covariance:
# [[0.04217824 0.00154232 0.00454026]
#  [0.00154232 0.00081352 0.00218856]
#  [0.00454026 0.00218856 0.0066325 ]]
# SN-109: μ = 41.752 ± 0.081, s = 0.929 ± 0.029
#
# Fitting SN-110...
# Fitting with Minuit
# Chi2 = 17.401174556250265
# ndf = 17
# Fitted values:
# [-2.5221176   1.30080567 44.43511942]
# Errors:
# [2.00980062 0.18581942 0.26921047]
# Covariance:
# [[ 4.03929854 -0.3468835  -0.46629989]
#  [-0.3468835   0.03452886  0.0492165 ]
#  [-0.46629989  0.0492165   0.07247428]]
# SN-110: μ = 44.435 ± 0.269, s = 1.301 ± 0.186
#
# Fitting SN-111...
# Fitting with Minuit
# Chi2 = 25.847661021004612
# ndf = 17
# Fitted values:
# [-0.21866522  0.97569771 41.32347629]
# Errors:
# [0.16285184 0.0214408  0.06525904]
# Covariance:
# [[0.02652072 0.00265297 0.00785458]
#  [0.00265297 0.00045971 0.00126787]
#  [0.00785458 0.00126787 0.00425874]]
# SN-111: μ = 41.323 ± 0.065, s = 0.976 ± 0.021
#
# Fitting SN-112...
# Fitting with Minuit
# Chi2 = 28.008566760748916
# ndf = 17
# Fitted values:
# [-0.50762272  1.0529863  41.98776735]
# Errors:
# [0.62443789 0.0564214  0.11292799]
# Covariance:
# [[ 0.38992268 -0.02616707 -0.04089441]
#  [-0.02616707  0.00318337  0.00606431]
#  [-0.04089441  0.00606431  0.01275273]]
# SN-112: μ = 41.988 ± 0.113, s = 1.053 ± 0.056
#
# Fitting SN-113...
# Fitting with Minuit
# Chi2 = 22.894829259391788
# ndf = 17
# Fitted values:
# [-0.04843459  1.08416702 43.40146405]
# Errors:
# [0.70072384 0.08004173 0.14714218]
# Covariance:
# [[ 0.4910139  -0.04334507 -0.06901667]
#  [-0.04334507  0.00640668  0.01145817]
#  [-0.06901667  0.01145817  0.02165082]]
# SN-113: μ = 43.401 ± 0.147, s = 1.084 ± 0.080
#
# Fitting SN-114...
# Fitting with Minuit
# Chi2 = 14.552708959456094
# ndf = 17
# Fitted values:
# [-1.6620296   1.09839319 44.16827835]
# Errors:
# [1.21305133 0.12103494 0.19515201]
# Covariance:
# [[ 1.47149352 -0.12830144 -0.18482295]
#  [-0.12830144  0.01464946  0.02306008]
#  [-0.18482295  0.02306008  0.03808431]]
# SN-114: μ = 44.168 ± 0.195, s = 1.098 ± 0.121
#
# Fitting SN-115...
# Fitting with Minuit
# Chi2 = 16.716923628554557
# ndf = 17
# Fitted values:
# [ 2.44094503  0.92422211 42.55810291]
# Errors:
# [0.24599565 0.03604205 0.0909339 ]
# Covariance:
# [[0.06051386 0.00015617 0.00161905]
#  [0.00015617 0.00129903 0.00311795]
#  [0.00161905 0.00311795 0.00826897]]
# SN-115: μ = 42.558 ± 0.091, s = 0.924 ± 0.036
#
# Fitting SN-116...
# Fitting with Minuit
# Chi2 = 11.20520366209146
# ndf = 17
# Fitted values:
# [ 1.48253911  1.08839358 43.3302241 ]
# Errors:
# [0.5758605  0.07596219 0.1444516 ]
# Covariance:
# [[ 0.33161531 -0.03026393 -0.05023218]
#  [-0.03026393  0.00577025  0.01071106]
#  [-0.05023218  0.01071106  0.02086626]]
# SN-116: μ = 43.330 ± 0.144, s = 1.088 ± 0.076
#
# Fitting SN-117...
# Fitting with Minuit
# Chi2 = 7.7477042504748574
# ndf = 17
# Fitted values:
# [-1.51976199  0.95889    43.31781767]
# Errors:
# [0.05985858 0.00675301 0.03309968]
# Covariance:
# [[ 3.58304956e-03 -7.11520418e-06  1.95219112e-04]
#  [-7.11520418e-06  4.56031914e-05  1.04192796e-04]
#  [ 1.95219112e-04  1.04192796e-04  1.09558900e-03]]
# SN-117: μ = 43.318 ± 0.033, s = 0.959 ± 0.007
#
# Fitting SN-118...
# Fitting with Minuit
# Chi2 = 8.92585441572398
# ndf = 17
# Fitted values:
# [-2.85403683  0.91964175 43.00612566]
# Errors:
# [0.79647074 0.05694412 0.10584843]
# Covariance:
# [[ 0.63436564 -0.03613097 -0.04360353]
#  [-0.03613097  0.00324263  0.00543728]
#  [-0.04360353  0.00543728  0.01120389]]
# SN-118: μ = 43.006 ± 0.106, s = 0.920 ± 0.057
#
# Fitting SN-119...
# Fitting with Minuit
# Chi2 = 16.32605711712555
# ndf = 17
# Fitted values:
# [-3.96708093  0.95922135 41.16110779]
# Errors:
# [0.7274199  0.04089981 0.08620497]
# Covariance:
# [[ 0.52913971 -0.02199619 -0.0202092 ]
#  [-0.02199619  0.00167279  0.00295882]
#  [-0.0202092   0.00295882  0.0074313 ]]
# SN-119: μ = 41.161 ± 0.086, s = 0.959 ± 0.041
#
# Fitting SN-120...
# Fitting with Minuit
# Chi2 = 30.521464775388097
# ndf = 17
# Fitted values:
# [ 0.74523122  1.10156925 42.80896428]
# Errors:
# [0.5859295  0.07253117 0.14013489]
# Covariance:
# [[ 0.34331337 -0.03064431 -0.0512141 ]
#  [-0.03064431  0.00526077  0.00990002]
#  [-0.0512141   0.00990002  0.01963779]]
# SN-120: μ = 42.809 ± 0.140, s = 1.102 ± 0.073
#
# Fitting SN-121...
# Fitting with Minuit
# Chi2 = 17.66081951849489
# ndf = 17
# Fitted values:
# [3.75403983e-02 8.26736053e-01 4.28192366e+01]
# Errors:
# [0.32781384 0.03750765 0.09366426]
# Covariance:
# [[ 0.10746191 -0.00642123 -0.01118231]
#  [-0.00642123  0.00140682  0.00330406]
#  [-0.01118231  0.00330406  0.00877299]]
# SN-121: μ = 42.819 ± 0.094, s = 0.827 ± 0.038
#
# Fitting SN-122...
# Fitting with Minuit
# Chi2 = 13.570384702879062
# ndf = 17
# Fitted values:
# [ 0.99059585  1.22018207 44.08432739]
# Errors:
# [0.83065365 0.11482303 0.19801575]
# Covariance:
# [[ 0.68998549 -0.07452585 -0.11832767]
#  [-0.07452585  0.01318433  0.02242024]
#  [-0.11832767  0.02242024  0.03921024]]
# SN-122: μ = 44.084 ± 0.198, s = 1.220 ± 0.115
#
# Fitting SN-123...
# Fitting with Minuit
# Chi2 = 28.4533012416516
# ndf = 17
# Fitted values:
# [-0.71088326  0.91097248 40.9692431 ]
# Errors:
# [0.36243416 0.03180515 0.08304459]
# Covariance:
# [[ 0.13135852 -0.00619208 -0.00949697]
#  [-0.00619208  0.00101157  0.00243238]
#  [-0.00949697  0.00243238  0.0068964 ]]
# SN-123: μ = 40.969 ± 0.083, s = 0.911 ± 0.032
#
# Fitting SN-124...
# Fitting with Minuit
# Chi2 = 16.86772560038995
# ndf = 17
# Fitted values:
# [ 1.66806954  1.11365782 42.88113983]
# Errors:
# [0.57110687 0.07976185 0.15423598]
# Covariance:
# [[ 0.32616306 -0.03046402 -0.05273499]
#  [-0.03046402  0.00636195  0.01206837]
#  [-0.05273499  0.01206837  0.02378874]]
# SN-124: μ = 42.881 ± 0.154, s = 1.114 ± 0.080
#
# Fitting SN-125...
# Fitting with Minuit
# Chi2 = 18.462634669202725
# ndf = 17
# Fitted values:
# [-0.24187302  1.02368999 42.95414714]
# Errors:
# [0.6266408  0.06782667 0.1307932 ]
# Covariance:
# [[ 0.39267869 -0.03101906 -0.04884762]
#  [-0.03101906  0.00460046  0.00855468]
#  [-0.04884762  0.00855468  0.01710686]]
# SN-125: μ = 42.954 ± 0.131, s = 1.024 ± 0.068
#
# Fitting SN-126...
# Fitting with Minuit
# Chi2 = 19.041039339959628
# ndf = 17
# Fitted values:
# [-3.07460537  1.05160864 42.40002995]
# Errors:
# [0.87172635 0.0618808  0.11292175]
# Covariance:
# [[ 0.75990682 -0.04224515 -0.05141725]
#  [-0.04224515  0.00382923  0.00640838]
#  [-0.05141725  0.00640838  0.01275132]]
# SN-126: μ = 42.400 ± 0.113, s = 1.052 ± 0.062
#
# Fitting SN-127...
# Fitting with Minuit
# Chi2 = 8.860825520797023
# ndf = 17
# Fitted values:
# [ 0.37806214  1.00217812 43.57024652]
# Errors:
# [0.6091421  0.0742562  0.14252079]
# Covariance:
# [[ 0.3710541  -0.03412755 -0.05712706]
#  [-0.03412755  0.00551398  0.01029175]
#  [-0.05712706  0.01029175  0.02031218]]
# SN-127: μ = 43.570 ± 0.143, s = 1.002 ± 0.074
#
# Fitting SN-128...
# Fitting with Minuit
# Chi2 = 14.842521251893634
# ndf = 17
# Fitted values:
# [-2.29923163  1.02480401 43.61716656]
# Errors:
# [0.07056863 0.0097838  0.03674688]
# Covariance:
# [[ 4.97993109e-03 -1.79697647e-05  2.62775805e-04]
#  [-1.79697647e-05  9.57226670e-05  2.10900714e-04]
#  [ 2.62775805e-04  2.10900714e-04  1.35033315e-03]]
# SN-128: μ = 43.617 ± 0.037, s = 1.025 ± 0.010
#
# Fitting SN-129...
# Fitting with Minuit
# Chi2 = 7.935762742941715
# ndf = 17
# Fitted values:
# [ 0.58852796  1.0050651  44.13050774]
# Errors:
# [0.65980808 0.09428447 0.17391581]
# Covariance:
# [[ 0.43534671 -0.0446524  -0.07413675]
#  [-0.0446524   0.00888956  0.01608584]
#  [-0.07413675  0.01608584  0.03024671]]
# SN-129: μ = 44.131 ± 0.174, s = 1.005 ± 0.094
#
# Fitting SN-130...
# Fitting with Minuit
# Chi2 = 12.098890124917723
# ndf = 17
# Fitted values:
# [ 2.72367627  1.12749215 43.37787338]
# Errors:
# [0.40694715 0.06902725 0.13650421]
# Covariance:
# [[ 0.16560598 -0.00897768 -0.01451516]
#  [-0.00897768  0.00476476  0.0092117 ]
#  [-0.01451516  0.0092117   0.0186334 ]]
# SN-130: μ = 43.378 ± 0.137, s = 1.127 ± 0.069
#
# Fitting SN-131...
# Fitting with Minuit
# Chi2 = 14.54645224848322
# ndf = 17
# Fitted values:
# [-1.89983041  1.00751919 40.28490646]
# Errors:
# [0.57245196 0.04215664 0.09415931]
# Covariance:
# [[ 0.32770124 -0.01703821 -0.02508474]
#  [-0.01703821  0.00177718  0.00365787]
#  [-0.02508474  0.00365787  0.00886598]]
# SN-131: μ = 40.285 ± 0.094, s = 1.008 ± 0.042
#
# Fitting SN-132...
# Fitting with Minuit
# Chi2 = 17.72948040801201
# ndf = 17
# Fitted values:
# [ 1.89457739  1.01775789 41.23218872]
# Errors:
# [0.26496421 0.03644777 0.09303954]
# Covariance:
# [[ 0.07020603 -0.00088826 -0.00029312]
#  [-0.00088826  0.00132844  0.00323404]
#  [-0.00029312  0.00323404  0.00865636]]
# SN-132: μ = 41.232 ± 0.093, s = 1.018 ± 0.036
#
# Fitting SN-133...
# Fitting with Minuit
# Chi2 = 5.731716551274225
# ndf = 17
# Fitted values:
# [ 0.34090604  0.86897381 43.59315496]
# Errors:
# [0.47572928 0.06121015 0.12753148]
# Covariance:
# [[ 0.22631835 -0.01927495 -0.03296513]
#  [-0.01927495  0.00374668  0.00752289]
#  [-0.03296513  0.00752289  0.01626428]]
# SN-133: μ = 43.593 ± 0.128, s = 0.869 ± 0.061
#
# Fitting SN-134...
# Fitting with Minuit
# Chi2 = 18.50801864409126
# ndf = 17
# Fitted values:
# [-1.60926974  0.88043499 42.92521924]
# Errors:
# [0.66097531 0.05420007 0.10728855]
# Covariance:
# [[ 0.43688836 -0.02785351 -0.03978643]
#  [-0.02785351  0.00293765  0.00539984]
#  [-0.03978643  0.00539984  0.01151083]]
# SN-134: μ = 42.925 ± 0.107, s = 0.880 ± 0.054
#
# Fitting SN-135...
# Fitting with Minuit
# Chi2 = 10.980763588377192
# ndf = 17
# Fitted values:
# [ 1.52228728  0.92734291 42.77010667]
# Errors:
# [2.7064342  0.05095269 0.01456295]
# Covariance:
# [[ 7.32478610e+00 -1.37727912e-01 -1.65606860e-02]
#  [-1.37727912e-01  2.59617709e-03  3.14787312e-04]
#  [-1.65606860e-02  3.14787312e-04  2.12079543e-04]]
# SN-135: μ = 42.770 ± 0.015, s = 0.927 ± 0.051
#
# Fitting SN-136...
# Fitting with Minuit
# Chi2 = 18.671425807088657
# ndf = 17
# Fitted values:
# [-0.36700864  1.02339784 42.86309543]
# Errors:
# [0.6280618  0.06260181 0.12209422]
# Covariance:
# [[ 0.39446163 -0.02996146 -0.04752129]
#  [-0.02996146  0.00391899  0.00732716]
#  [-0.04752129  0.00732716  0.014907  ]]
# SN-136: μ = 42.863 ± 0.122, s = 1.023 ± 0.063
#
# Fitting SN-137...
# Fitting with Minuit
# Chi2 = 17.358127858104353
# ndf = 17
# Fitted values:
# [-1.55340096  1.05370012 42.50301826]
# Errors:
# [0.77705244 0.06288903 0.116156  ]
# Covariance:
# [[ 0.60381049 -0.03936941 -0.05570378]
#  [-0.03936941  0.00395503  0.0068791 ]
#  [-0.05570378  0.0068791   0.01349222]]
# SN-137: μ = 42.503 ± 0.116, s = 1.054 ± 0.063
#
# Fitting SN-138...
# Fitting with Minuit
# Chi2 = 21.50883022098318
# ndf = 17
# Fitted values:
# [ 0.8447191   0.92020353 42.83128063]
# Errors:
# [0.35803701 0.0441553  0.10120501]
# Covariance:
# [[ 0.1281905  -0.00776055 -0.01300772]
#  [-0.00776055  0.00194969  0.00425794]
#  [-0.01300772  0.00425794  0.01024245]]
# SN-138: μ = 42.831 ± 0.101, s = 0.920 ± 0.044
#
# Fitting SN-139...
# Fitting with Minuit
# Chi2 = 29.72931843561644
# ndf = 17
# Fitted values:
# [ 1.85093323  0.98313467 42.78656634]
# Errors:
# [2.78294057 0.04049278 0.01254458]
# Covariance:
# [[ 7.74475821e+00 -1.12552309e-01 -5.96466412e-03]
#  [-1.12552309e-01  1.63966533e-03  8.84536842e-05]
#  [-5.96466412e-03  8.84536842e-05  1.57366407e-04]]
# SN-139: μ = 42.787 ± 0.013, s = 0.983 ± 0.040
#
# Fitting SN-140...
# Fitting with Minuit
# Chi2 = 10.861796951374863
# ndf = 17
# Fitted values:
# [ 0.93764327  1.19481075 43.36647195]
# Errors:
# [0.71480693 0.09373207 0.16967877]
# Covariance:
# [[ 0.51094894 -0.05082405 -0.08322836]
#  [-0.05082405  0.0087857   0.01562468]
#  [-0.08322836  0.01562468  0.02879088]]
# SN-140: μ = 43.366 ± 0.170, s = 1.195 ± 0.094
#
# Fitting SN-141...
# Fitting with Minuit
# Chi2 = 11.088351360866927
# ndf = 17
# Fitted values:
# [-1.5903748   0.93283073 42.59309719]
# Errors:
# [0.68738591 0.05571662 0.10889984]
# Covariance:
# [[ 0.47249938 -0.02982434 -0.04233292]
#  [-0.02982434  0.00310434  0.00565528]
#  [-0.04233292  0.00565528  0.01185917]]
# SN-141: μ = 42.593 ± 0.109, s = 0.933 ± 0.056
#
# Fitting SN-142...
# Fitting with Minuit
# Chi2 = 13.477178117496226
# ndf = 17
# Fitted values:
# [-0.45782377  1.03097848 43.86861104]
# Errors:
# [0.75971495 0.08600604 0.15520497]
# Covariance:
# [[ 0.5771668  -0.05189875 -0.0808752 ]
#  [-0.05189875  0.00739704  0.01296557]
#  [-0.0808752   0.01296557  0.02408858]]
# SN-142: μ = 43.869 ± 0.155, s = 1.031 ± 0.086
#
# Fitting SN-143...
# Fitting with Minuit
# Chi2 = 28.925324479602605
# ndf = 17
# Fitted values:
# [-0.30922961  1.06125004 41.80563165]
# Errors:
# [0.6204437  0.05676345 0.11336772]
# Covariance:
# [[ 0.38495039 -0.02589343 -0.04022729]
#  [-0.02589343  0.00322209  0.0061279 ]
#  [-0.04022729  0.0061279   0.01285224]]
# SN-143: μ = 41.806 ± 0.113, s = 1.061 ± 0.057
#
# Fitting SN-144...
# Fitting with Minuit
# Chi2 = 20.095400301544693
# ndf = 17
# Fitted values:
# [ 0.54928447  1.02649211 43.95444187]
# Errors:
# [0.68406356 0.08608723 0.15649337]
# Covariance:
# [[ 0.46794295 -0.04422557 -0.07002278]
#  [-0.04422557  0.00741101  0.01313215]
#  [-0.07002278  0.01313215  0.02449018]]
# SN-144: μ = 43.954 ± 0.156, s = 1.026 ± 0.086
#
# Fitting SN-145...
# Fitting with Minuit
# Chi2 = 10.104436989987537
# ndf = 17
# Fitted values:
# [ 1.9464719   0.96323624 43.45656692]
# Errors:
# [0.35683359 0.05372074 0.11533996]
# Covariance:
# [[ 0.12733021 -0.00830488 -0.01427081]
#  [-0.00830488  0.00288592  0.00598391]
#  [-0.01427081  0.00598391  0.01330331]]
# SN-145: μ = 43.457 ± 0.115, s = 0.963 ± 0.054
#
# Fitting SN-146...
# Fitting with Minuit
# Chi2 = 9.38269912908089
# ndf = 17
# Fitted values:
# [-2.48950473  0.91458847 42.96615948]
# Errors:
# [0.70369227 0.0559391  0.1094605 ]
# Covariance:
# [[ 0.49518281 -0.03041633 -0.04165339]
#  [-0.03041633  0.00312918  0.00566313]
#  [-0.04165339  0.00566313  0.0119816 ]]
# SN-146: μ = 42.966 ± 0.109, s = 0.915 ± 0.056
#
# Fitting SN-147...
# Fitting with Minuit
# Chi2 = 26.893282067420806
# ndf = 17
# Fitted values:
# [-1.6819956   0.93660792 42.07764137]
# Errors:
# [0.58350774 0.04454299 0.09469718]
# Covariance:
# [[ 0.34048129 -0.01853566 -0.02444282]
#  [-0.01853566  0.00198408  0.0038395 ]
#  [-0.02444282  0.0038395   0.00896756]]
# SN-147: μ = 42.078 ± 0.095, s = 0.937 ± 0.045
#
# Fitting SN-148...
# Fitting with Minuit
# Chi2 = 10.67107115877384
# ndf = 17
# Fitted values:
# [ 1.40637608  0.91000501 43.2887715 ]
# Errors:
# [0.33853957 0.04871291 0.11026093]
# Covariance:
# [[ 0.11460904 -0.00694074 -0.01203295]
#  [-0.00694074  0.00237295  0.00516351]
#  [-0.01203295  0.00516351  0.01215747]]
# SN-148: μ = 43.289 ± 0.110, s = 0.910 ± 0.049
#
# Fitting SN-149...
# Fitting with Minuit
# Chi2 = 18.076565610542534
# ndf = 17
# Fitted values:
# [-2.1411723   0.99283699 43.096672  ]
# Errors:
# [0.45449044 0.00754406 0.04336644]
# Covariance:
# [[ 2.06561557e-01 -5.37544763e-04  1.24818737e-02]
#  [-5.37544763e-04  5.69129120e-05  9.98190055e-05]
#  [ 1.24818737e-02  9.98190055e-05  1.88064793e-03]]
# SN-149: μ = 43.097 ± 0.043, s = 0.993 ± 0.008
#
# Successfully fitted 150 supernovae
#
# Fitting Results Summary:
# SN	Redshift	μ ± σ_μ		s ± σ_s		χ²/ndf
# ----------------------------------------------------------------------
# 0	0.867		43.653 ± 0.156	1.040 ± 0.086	0.64
# 1	0.442		41.935 ± 0.082	0.935 ± 0.029	0.69
# 2	0.949		43.731 ± 0.166	1.106 ± 0.101	0.65
# 3	1.184		44.248 ± 0.184	1.029 ± 0.108	0.91
# 4	0.213		39.944 ± 0.087	1.004 ± 0.033	1.39
# 5	0.366		41.399 ± 0.088	0.944 ± 0.039	1.37
# 6	0.633		42.556 ± 0.118	1.027 ± 0.054	0.92
# 7	0.562		42.360 ± 0.099	0.902 ± 0.045	0.80
# 8	0.616		42.491 ± 0.110	0.987 ± 0.049	0.73
# 9	0.633		42.731 ± 0.100	0.897 ± 0.047	1.05
# 10	0.900		43.713 ± 0.148	1.029 ± 0.080	0.62
# 11	1.034		43.754 ± 0.140	0.932 ± 0.071	0.91
# 12	0.658		42.962 ± 0.129	1.080 ± 0.072	1.18
# 13	0.782		43.179 ± 0.133	1.040 ± 0.073	0.86
# 14	0.790		43.021 ± 0.115	0.902 ± 0.054	0.56
# 15	0.819		43.563 ± 0.034	1.163 ± 0.009	0.95
# 16	0.976		43.946 ± 0.147	0.997 ± 0.077	0.58
# 17	0.892		43.723 ± 0.183	1.185 ± 0.108	1.27
# 18	0.972		43.735 ± 0.136	0.939 ± 0.071	0.84
# 19	0.958		43.794 ± 0.136	0.940 ± 0.075	0.65
# 20	0.524		42.175 ± 0.108	1.019 ± 0.055	0.80
# 21	0.634		42.851 ± 0.030	1.037 ± 0.004	0.76
# 22	0.629		42.778 ± 0.116	0.971 ± 0.056	1.15
# 23	0.739		43.211 ± 0.150	1.120 ± 0.087	0.78
# 24	0.491		42.092 ± 0.099	0.912 ± 0.045	0.99
# 25	1.009		43.853 ± 0.120	0.963 ± 0.057	0.20
# 26	0.734		43.137 ± 0.047	1.018 ± 0.016	0.95
# 27	0.590		42.584 ± 0.040	1.092 ± 0.013	0.60
# 28	0.857		43.497 ± 0.041	0.988 ± 0.014	1.01
# 29	0.960		43.731 ± 0.117	0.970 ± 0.056	0.54
# 30	0.893		43.665 ± 0.126	1.060 ± 0.062	0.91
# 31	0.343		41.015 ± 0.092	0.948 ± 0.037	0.66
# 32	0.866		43.768 ± 0.053	1.209 ± 0.021	0.49
# 33	0.775		43.180 ± 0.117	0.932 ± 0.059	0.78
# 34	0.790		43.246 ± 0.135	0.988 ± 0.068	1.28
# 35	0.352		41.260 ± 0.087	0.928 ± 0.031	0.99
# 36	0.846		43.509 ± 0.138	0.996 ± 0.070	0.84
# 37	0.687		42.801 ± 0.106	0.885 ± 0.048	1.63
# 38	0.918		43.784 ± 0.193	1.177 ± 0.111	1.10
# 39	0.682		42.741 ± 0.100	0.929 ± 0.053	1.02
# 40	0.752		43.119 ± 0.123	1.012 ± 0.067	0.53
# 41	0.497		42.142 ± 0.114	0.993 ± 0.053	0.65
# 42	0.947		43.809 ± 0.042	1.020 ± 0.014	0.98
# 43	0.772		43.339 ± 0.148	1.106 ± 0.079	0.50
# 44	1.066		43.934 ± 0.168	1.037 ± 0.097	0.52
# 45	0.414		41.630 ± 0.102	1.017 ± 0.044	0.58
# 46	0.692		42.760 ± 0.052	0.939 ± 0.018	0.85
# 47	0.463		42.128 ± 0.038	1.012 ± 0.011	0.81
# 48	0.936		43.781 ± 0.166	1.105 ± 0.102	0.78
# 49	0.881		43.764 ± 0.188	1.209 ± 0.126	1.17
# 50	0.924		43.694 ± 0.161	1.097 ± 0.093	0.93
# 51	0.699		42.874 ± 0.122	1.035 ± 0.058	0.78
# 52	0.787		43.135 ± 0.038	0.891 ± 0.011	0.73
# 53	0.693		43.031 ± 0.065	0.967 ± 0.025	1.04
# 54	0.531		42.305 ± 0.094	0.994 ± 0.039	0.75
# 55	0.961		43.728 ± 0.131	0.924 ± 0.071	0.49
# 56	0.770		43.027 ± 0.108	0.944 ± 0.049	1.07
# 57	0.572		42.689 ± 0.154	1.206 ± 0.083	0.94
# 58	0.495		42.191 ± 0.093	1.007 ± 0.037	0.73
# 59	0.963		43.719 ± 0.127	0.885 ± 0.064	0.75
# 60	0.947		44.007 ± 0.183	1.172 ± 0.114	0.73
# 61	0.714		43.116 ± 0.127	1.057 ± 0.070	1.31
# 62	0.742		43.051 ± 0.113	0.990 ± 0.052	1.13
# 63	0.398		41.554 ± 0.102	1.019 ± 0.044	0.97
# 64	0.859		43.453 ± 0.142	1.009 ± 0.074	1.11
# 65	0.507		41.984 ± 0.091	0.886 ± 0.040	0.74
# 66	0.907		43.664 ± 0.162	1.084 ± 0.094	0.83
# 67	0.880		43.863 ± 0.190	1.207 ± 0.111	1.11
# 68	0.609		42.624 ± 0.105	0.953 ± 0.046	0.96
# 69	0.597		42.582 ± 0.015	1.085 ± 0.074	1.43
# 70	1.184		44.459 ± 0.197	1.089 ± 0.109	0.80
# 71	0.880		43.540 ± 0.121	0.991 ± 0.057	1.28
# 72	0.473		41.955 ± 0.080	0.900 ± 0.028	1.04
# 73	0.736		43.387 ± 0.147	1.109 ± 0.083	0.70
# 74	0.579		42.520 ± 0.108	0.928 ± 0.050	0.96
# 75	0.961		44.019 ± 0.041	1.084 ± 0.011	0.43
# 76	1.142		44.109 ± 0.156	0.905 ± 0.079	0.79
# 77	0.648		42.784 ± 0.127	1.088 ± 0.062	0.85
# 78	1.263		44.595 ± 0.222	1.150 ± 0.132	0.95
# 79	0.926		43.864 ± 0.046	1.163 ± 0.019	0.85
# 80	0.976		43.660 ± 0.122	0.899 ± 0.069	0.45
# 81	1.079		44.098 ± 0.193	1.114 ± 0.121	0.82
# 82	0.814		43.448 ± 0.104	0.997 ± 0.047	0.52
# 83	0.768		43.376 ± 0.056	1.152 ± 0.021	0.60
# 84	0.663		42.807 ± 0.114	0.998 ± 0.057	1.54
# 85	0.712		43.068 ± 0.061	1.105 ± 0.022	1.69
# 86	0.882		43.546 ± 0.050	0.938 ± 0.013	0.93
# 87	0.866		43.502 ± 0.125	1.015 ± 0.061	1.27
# 88	0.508		42.196 ± 0.121	1.087 ± 0.056	0.74
# 89	0.918		43.648 ± 0.154	1.015 ± 0.080	0.35
# 90	0.807		43.241 ± 0.110	0.907 ± 0.049	0.97
# 91	0.834		43.506 ± 0.113	0.957 ± 0.052	0.48
# 92	0.478		42.073 ± 0.110	0.996 ± 0.052	1.40
# 93	0.728		43.100 ± 0.148	1.110 ± 0.080	1.05
# 94	0.643		42.832 ± 0.018	1.185 ± 0.101	1.28
# 95	0.730		42.952 ± 0.119	0.973 ± 0.060	0.65
# 96	0.725		42.994 ± 0.138	1.035 ± 0.071	1.72
# 97	1.108		44.173 ± 0.171	1.003 ± 0.099	0.82
# 98	0.507		42.165 ± 0.102	1.073 ± 0.044	0.81
# 99	0.665		42.701 ± 0.111	0.980 ± 0.050	0.52
# 100	0.626		42.621 ± 0.111	1.023 ± 0.051	0.54
# 101	0.661		42.919 ± 0.113	1.014 ± 0.052	1.30
# 102	0.406		41.692 ± 0.098	0.988 ± 0.049	0.74
# 103	0.616		42.804 ± 0.141	1.198 ± 0.059	1.03
# 104	0.597		42.589 ± 0.095	0.983 ± 0.039	0.48
# 105	0.805		43.401 ± 0.126	1.027 ± 0.073	0.41
# 106	0.696		42.787 ± 0.090	0.891 ± 0.035	1.05
# 107	1.200		44.314 ± 0.058	0.947 ± 0.022	0.64
# 108	0.976		43.669 ± 0.054	0.947 ± 0.022	0.68
# 109	0.427		41.752 ± 0.081	0.929 ± 0.029	1.00
# 110	1.121		44.435 ± 0.269	1.301 ± 0.186	1.02
# 111	0.390		41.323 ± 0.065	0.976 ± 0.021	1.52
# 112	0.468		41.988 ± 0.113	1.053 ± 0.056	1.65
# 113	0.813		43.401 ± 0.147	1.084 ± 0.080	1.35
# 114	1.061		44.168 ± 0.195	1.098 ± 0.121	0.86
# 115	0.630		42.558 ± 0.091	0.924 ± 0.036	0.98
# 116	0.763		43.330 ± 0.144	1.088 ± 0.076	0.66
# 117	0.781		43.318 ± 0.033	0.959 ± 0.007	0.46
# 118	0.726		43.006 ± 0.106	0.920 ± 0.057	0.53
# 119	0.349		41.161 ± 0.086	0.959 ± 0.041	0.96
# 120	0.666		42.809 ± 0.140	1.102 ± 0.073	1.80
# 121	0.694		42.819 ± 0.094	0.827 ± 0.038	1.04
# 122	1.002		44.084 ± 0.198	1.220 ± 0.115	0.80
# 123	0.348		40.969 ± 0.083	0.911 ± 0.032	1.67
# 124	0.631		42.881 ± 0.154	1.114 ± 0.080	0.99
# 125	0.723		42.954 ± 0.131	1.024 ± 0.068	1.09
# 126	0.533		42.400 ± 0.113	1.052 ± 0.062	1.12
# 127	0.872		43.570 ± 0.143	1.002 ± 0.074	0.52
# 128	0.885		43.617 ± 0.037	1.025 ± 0.010	0.87
# 129	1.135		44.131 ± 0.174	1.005 ± 0.094	0.47
# 130	0.797		43.378 ± 0.137	1.127 ± 0.069	0.71
# 131	0.227		40.285 ± 0.094	1.008 ± 0.042	0.86
# 132	0.346		41.232 ± 0.093	1.018 ± 0.036	1.04
# 133	0.943		43.593 ± 0.128	0.869 ± 0.061	0.34
# 134	0.719		42.925 ± 0.107	0.880 ± 0.054	1.09
# 135	0.666		42.770 ± 0.015	0.927 ± 0.051	0.65
# 136	0.650		42.863 ± 0.122	1.023 ± 0.063	1.10
# 137	0.567		42.503 ± 0.116	1.054 ± 0.063	1.02
# 138	0.684		42.831 ± 0.101	0.920 ± 0.044	1.27
# 139	0.696		42.787 ± 0.013	0.983 ± 0.040	1.75
# 140	0.743		43.366 ± 0.170	1.195 ± 0.094	0.64
# 141	0.637		42.593 ± 0.109	0.933 ± 0.056	0.65
# 142	0.935		43.869 ± 0.155	1.031 ± 0.086	0.79
# 143	0.459		41.806 ± 0.113	1.061 ± 0.057	1.70
# 144	1.039		43.954 ± 0.156	1.026 ± 0.086	1.18
# 145	0.874		43.457 ± 0.115	0.963 ± 0.054	0.59
# 146	0.720		42.966 ± 0.109	0.915 ± 0.056	0.55
# 147	0.523		42.078 ± 0.095	0.937 ± 0.045	1.58
# 148	0.784		43.289 ± 0.110	0.910 ± 0.049	0.63
# 149	0.721		43.097 ± 0.043	0.993 ± 0.008	1.06
#
# Note: All fits include intrinsic scatter σ_int = 0.120 mag

# %% [markdown]
# We now display the first nine fitted lightcurves in order to give a relevant and efficient example of the results of the Minuit part.

# %%
# Plot fitted lightcurves for visualization
if fitting_results:
    # Select a subset of supernovae to plot (first 9 for a 3x3 grid)
    n_plot = min(9, len(fitting_results))
    
    figure(figsize=(15, 12))
    
    for i in range(n_plot):
        result = fitting_results[i]
        sn_number = result['sn_number']
        redshift = result['redshift']
        
        # Load observed data
        filename = f'data/Data-LightCurves/EI2019-Data-LightCurves-SN-{sn_number}_lightcurve.txt'
        if os.path.exists(filename):
            data = np.loadtxt(filename)
            t_obs = data[:, 0]
            mag_obs = data[:, 1]
            mag_err = data[:, 2]
            
            # Convert to rest frame
            t_rest = t_obs / (1 + redshift)
            
            # Generate fitted lightcurve
            t_model = np.linspace(t_rest.min() - 5, t_rest.max() + 5, 200)
            fitted_pars = [result['t0'], result['s'], result['mu']]
            mag_model = lc_template(t_model, fitted_pars)
            
            # Plot in subplot
            subplot(3, 3, i + 1)
            
            # Plot observed data
            errorbar(t_rest, mag_obs, yerr=mag_err, fmt='o', 
                    capsize=3, markersize=4, alpha=0.7, label='Observed', color='blue')
            
            # Plot fitted model
            plot(t_model, mag_model, 'r-', linewidth=2, label='Fitted Model')
            
            # Formatting
            xlabel('Rest Frame Time (days)')
            ylabel('Magnitude')
            title(f'SN-{sn_number} (z={redshift:.3f})\nμ={result["mu"]:.2f}±{result["mu_err"]:.2f}, s={result["s"]:.2f}±{result["s_err"]:.2f}')
            grid(True, alpha=0.3)
            gca().invert_yaxis()  # Invert y-axis for magnitudes (brighter = lower values)
            
            if i == 0:  # Only show legend for first subplot
                legend(loc='upper right', fontsize=8)
    
    tight_layout()
    suptitle('Fitted Supernova Lightcurves (First 9 SNe)', fontsize=16, y=0.98)
    show()
    
    print(f"\nDisplayed fitted lightcurves for the first {n_plot} supernovae")
    print("Each plot shows:")
    print("- Blue points: Observed photometry with error bars")
    print("- Red line: Best-fit template lightcurve")
    print("- Title includes redshift and fitted parameters (μ, s)")
# Out:
# Displayed fitted lightcurves for the first 9 supernovae
# Each plot shows:
# - Blue points: Observed photometry with error bars
# - Red line: Best-fit template lightcurve
# - Title includes redshift and fitted parameters (μ, s)

# %% [markdown]
# For know, we display all the 150 fitted lightcurves to see global results of our first part.

# %%
# Create Hubble Diagram from fitted distance moduli
if fitting_results:
    # Extract data for plotting
    redshifts_fitted = [r['redshift'] for r in fitting_results]
    mu_fitted = [r['mu'] for r in fitting_results]
    mu_err_fitted = [r['mu_err'] for r in fitting_results]
    stretch_fitted = [r['s'] for r in fitting_results]
    
    # Plot Hubble Diagram
    figure(figsize=(12, 8))
    
    subplot(2, 2, 1)
    errorbar(redshifts_fitted, mu_fitted, yerr=mu_err_fitted, fmt='o', 
             capsize=3, markersize=6, alpha=0.7)
    xlabel('Redshift z')
    ylabel('Distance Modulus μ')
    title('Hubble Diagram from Fitted Lightcurves')
    grid(True, alpha=0.3)
    
    # Compare with theoretical prediction
    z_theory = np.linspace(0.1, max(redshifts_fitted), 100)
    mu_theory = cs.musn1a(z_theory, cosmo_pars)
    plot(z_theory, mu_theory, 'r-', label='Fiducial ΛCDM', linewidth=2)
    legend()
    
    # Plot stretch parameter distribution
    subplot(2, 2, 2)
    hist(stretch_fitted, bins=8, alpha=0.7, edgecolor='black')
    xlabel('Stretch Parameter s')
    ylabel('Number of SNe')
    title('Distribution of Stretch Parameters')
    axvline(1.0, color='red', linestyle='--', label='s = 1')
    legend()
    grid(True, alpha=0.3)
    
    # Plot residuals from fiducial cosmology
    subplot(2, 2, 3)
    mu_theory_at_z = cs.musn1a(np.array(redshifts_fitted), cosmo_pars)
    residuals = np.array(mu_fitted) - mu_theory_at_z
    errorbar(redshifts_fitted, residuals, yerr=mu_err_fitted, fmt='o', 
             capsize=3, markersize=6, alpha=0.7)
    axhline(0, color='red', linestyle='--')
    xlabel('Redshift z')
    ylabel('Δμ (obs - theory)')
    title('Residuals from Fiducial Cosmology')
    grid(True, alpha=0.3)
    
    # Plot χ² distribution
    subplot(2, 2, 4)
    chi2_reduced = [r['chi2_reduced'] for r in fitting_results if np.isfinite(r['chi2_reduced'])]
    hist(chi2_reduced, bins=8, alpha=0.7, edgecolor='black')
    xlabel('Reduced χ²')
    ylabel('Number of SNe')
    title('Distribution of Reduced χ²')
    axvline(1.0, color='red', linestyle='--', label='χ²/ndf = 1')
    legend()
    grid(True, alpha=0.3)
    
    tight_layout()
    show()
    
    # Print statistics
    print(f"\nStatistics for {len(fitting_results)} fitted supernovae:")
    print(f"Mean stretch parameter: {np.mean(stretch_fitted):.3f} ± {np.std(stretch_fitted):.3f}")
    print(f"Mean reduced χ²: {np.mean(chi2_reduced):.3f} ± {np.std(chi2_reduced):.3f}")
    print(f"RMS of residuals: {np.sqrt(np.mean(residuals**2)):.3f} mag")
# Out:
# Statistics for 150 fitted supernovae:
# Mean stretch parameter: 1.016 ± 0.089
# Mean reduced χ²: 0.904 ± 0.327
# RMS of residuals: 0.119 mag

# %% [markdown]
# ### CSV Export

# %% [markdown]
# Now, in order to obtain our primar results, we export are fitted values in a CSV file and display the five first rows as a verification.

# %%
# Export results to CSV file
if fitting_results:
    
    # Convert results to DataFrame
    df_results = pd.DataFrame(fitting_results)
    
    # Reorder columns for better readability
    column_order = ['sn_number', 'redshift', 'mu', 'mu_err', 's', 's_err', 't0', 't0_err', 
                   'chi2', 'ndf', 'chi2_reduced', 'sigma_int_used']
    df_results = df_results[column_order]
    
    # Add some additional computed columns for analysis
    df_results['mu_significance'] = df_results['mu'] / df_results['mu_err']
    df_results['s_significance'] = abs(df_results['s'] - 1.0) / df_results['s_err']
    
    # Create output filename with timestamp
    from datetime import datetime
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    output_filename = f'supernova_fitting_results_{timestamp}.csv'
    
    # Save to CSV
    df_results.to_csv(output_filename, index=False, float_format='%.6f')
    
    print(f"\n=== CSV Export Complete ===")
    print(f"Results saved to: {output_filename}")
    print(f"Number of supernovae: {len(df_results)}")
    print(f"Columns exported: {', '.join(df_results.columns)}")
    
    # Display basic statistics
    print(f"\n=== Summary Statistics ===")
    print(f"Distance modulus μ:")
    print(f"  Mean: {df_results['mu'].mean():.3f} ± {df_results['mu'].std():.3f}")
    print(f"  Range: [{df_results['mu'].min():.3f}, {df_results['mu'].max():.3f}]")
    print(f"Stretch parameter s:")
    print(f"  Mean: {df_results['s'].mean():.3f} ± {df_results['s'].std():.3f}")
    print(f"  Range: [{df_results['s'].min():.3f}, {df_results['s'].max():.3f}]")
    print(f"Reduced χ²:")
    print(f"  Mean: {df_results['chi2_reduced'].mean():.2f}")
    print(f"  Good fits (χ²/ndf < 2): {(df_results['chi2_reduced'] < 2).sum()}/{len(df_results)} ({100*(df_results['chi2_reduced'] < 2).mean():.1f}%)")
    
    # Display first few rows for verification
    print(f"\n=== First 5 rows of exported data ===")
    print(df_results.head().to_string(index=False, float_format=lambda x: f'{x:.4f}'))

else:
    print("No fitting results to export !")
# Out:
# === CSV Export Complete ===
# Results saved to: supernova_fitting_results_20250606_021821.csv
# Number of supernovae: 150
# Columns exported: sn_number, redshift, mu, mu_err, s, s_err, t0, t0_err, chi2, ndf, chi2_reduced, sigma_int_used, mu_significance, s_significance
#
# === Summary Statistics ===
# Distance modulus μ:
#   Mean: 43.010 ± 0.840
#   Range: [39.944, 44.595]
# Stretch parameter s:
#   Mean: 1.016 ± 0.089
#   Range: [0.827, 1.301]
# Reduced χ²:
#   Mean: 0.90
#   Good fits (χ²/ndf < 2): 150/150 (100.0%)
#
# === First 5 rows of exported data ===
#  sn_number  redshift      mu  mu_err      s  s_err      t0  t0_err    chi2  ndf  chi2_reduced  sigma_int_used  mu_significance  s_significance
#          0    0.8670 43.6531  0.1561 1.0398 0.0857 -0.2574  0.7381 10.8186   17        0.6364          0.1200         279.6137          0.4644
#          1    0.4420 41.9354  0.0816 0.9348 0.0291  3.1471  0.2106 11.6549   17        0.6856          0.1200         513.7956          2.2408
#          2    0.9487 43.7312  0.1658 1.1057 0.1007 -1.8812  1.0547 11.0106   17        0.6477          0.1200         263.7993          1.0489
#          3    1.1841 44.2484  0.1839 1.0288 0.1082 -0.4707  0.9498 15.5100   17        0.9124          0.1200         240.5989          0.2664
#          4    0.2129 39.9443  0.0872 1.0039 0.0326  0.6281  0.2897 23.6231   17        1.3896          0.1200         458.0783          0.1182

# %% [markdown]
# ### MCMC

# %% [markdown]
# The MCMC part work this way :
# From the CSV file, we are able to use the Monte-Carlo Method to obtain a density diagram of $\Omega_{m}$ and $\Omega_{\lambda}$ via the emcee library.
#
# In addition, we propose a distribution of $\Omega_{m}$ and $\Omega_{\lambda}$ from our walkers.

# %%
# Find the latest CSV file
csv_pattern = 'supernova_fitting_results_*.csv'
csv_files = glob.glob(csv_pattern)
if not csv_files:
    raise FileNotFoundError(f"No CSV files found matching pattern: {csv_pattern}")
latest_csv = max(csv_files, key=os.path.getmtime)
print(f"Using CSV file: {latest_csv}")

# Load data
df = pd.read_csv(latest_csv)
z = df['redshift'].values
mu_exp = df['mu'].values
sigma_mu_exp = df['mu_err'].values

# Check for NaN values
if np.any(np.isnan(z)) or np.any(np.isnan(mu_exp)) or np.any(np.isnan(sigma_mu_exp)):
    raise ValueError("Input data contains NaN values")

# Include intrinsic scatter
sigma_int = 0.12
sigma_total = np.sqrt(sigma_mu_exp**2 + sigma_int**2)

# Prediction function
def muPred(z, par):
    return cs.musn1a(z, {'omega_M_0': par[0], 'omega_lambda_0': par[1], 'h': par[2], 'w0': -1})

# Log prior for free parameters
def log_prior_free_pars(free_par):
    omega_m, omega_lambda = free_par
    if 0 <= omega_m <= 1 and 0 <= omega_lambda <= 1:
        return 0  # Uniform prior
    return -np.inf

# Log likelihood
def log_likelihood(par, z, mu_exp, sigma_total):
    mu_model = muPred(z, par)
    if np.any(np.isnan(mu_model)):
        return -np.inf  # Reject invalid models
    chi2 = np.sum((mu_model - mu_exp)**2 / sigma_total**2)
    return -0.5 * chi2

# Log probability
def log_prob_free_pars(free_par, fixed_h, z, mu_exp, sigma_total):
    par = np.array([free_par[0], free_par[1], fixed_h])
    lp = log_prior_free_pars(free_par)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(par, z, mu_exp, sigma_total)

# Fixed h value
fixed_h = 0.7

# Initial guess
guess = np.array([0.3, 0.7])  # omega_m, omega_lambda

# MCMC setup
ndim = 2  # Only omega_m and omega_lambda vary
nwalkers = 20
p0 = [guess + 1e-4 * np.random.randn(ndim) for _ in range(nwalkers)]

# Sampler
sampler = emcee.EnsembleSampler(nwalkers, ndim, log_prob_free_pars, args=(fixed_h, z, mu_exp, sigma_total))

# Burn-in
print("Burning")
pos, _, _ = sampler.run_mcmc(p0, 500, progress=True)
sampler.reset()

# Production run
print("Sampling")
sampler.run_mcmc(pos, 5000, progress=True)

# Convergence diagnostics
try:
    tau = sampler.get_autocorr_time()
    print(f"Autocorrelation time: omega_M = {tau[0]:.1f}, omega_lambda = {tau[1]:.1f}")
    print(f"Chain length per walker (10000) is {10000 / max(tau):.1f} times autocorrelation time")
except emcee.autocorr.AutocorrError:
    print("Warning: Autocorrelation time could not be reliably estimated. Chain may not be converged.")

# Acceptance fraction
acceptance = sampler.acceptance_fraction
print(f"Acceptance fraction: mean = {np.mean(acceptance):.3f}, std = {np.std(acceptance):.3f}")

# Get chain
chain = sampler.get_chain()

# Export chain to CSV
output_chain_filename = 'mcmc_chain.csv'
np.savetxt(output_chain_filename, chain.reshape(-1, ndim), delimiter=',', header='omega_M,omega_lambda', comments='')

# Flatten chain, discard burn-in
flat_chain = chain[1000:, :, :].reshape(-1, ndim)

# Compute best-fit and 68% CI (calculate before plotting)
omegaM_chain = flat_chain[:, 0]
omegaL_chain = flat_chain[:, 1]
omegaM_16, omegaM_50, omegaM_84 = np.percentile(omegaM_chain, [16, 50, 84])
omegaL_16, omegaL_50, omegaL_84 = np.percentile(omegaL_chain, [16, 50, 84])

# 2D histogram
plt.figure(figsize=(8, 6))
plt.hist2d(flat_chain[:, 0], flat_chain[:, 1], bins=50, cmap='Blues')
plt.colorbar(label='Density')
plt.scatter(omegaM_50, omegaL_50, c='g', marker='*', s=200, label=f'Best-fit ({omegaM_50:.3f}, {omegaL_50:.3f})')
plt.xlabel('omega_m')
plt.ylabel('omega_lambda')
plt.title('Posterior: omega_m vs omega_lambda')
plt.legend()
plt.show()

# Marginalized posteriors
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].hist(flat_chain[:, 0], bins=50, density=True, color='blue', alpha=0.7)
axes[0].set_xlabel('omega_m')
axes[0].set_title('omega_M Posterior')
axes[1].hist(flat_chain[:, 1], bins=50, density=True, color='blue', alpha=0.7)
axes[1].set_xlabel('omega_lambda')
axes[1].set_title('omega_lambda Posterior')
plt.tight_layout()
plt.show()

# Results
print(f"Best-fit omega_m = {omegaM_50:.3f} +{(omegaM_84 - omegaM_50):.3f} -{(omegaM_50 - omegaM_16):.3f} (68% CI)")
print(f"Best-fit omega_lambda = {omegaL_50:.3f} +{(omegaL_84 - omegaL_50):.3f} -{(omegaL_50 - omegaL_16):.3f} (68% CI)")
print(f"Fixed h = {fixed_h:.1f}")
# Out:
# Using CSV file: supernova_fitting_results_20250606_021821.csv
# Burning
# 100%|██████████| 500/500 [00:02<00:00, 184.75it/s]
# Sampling
# 100%|██████████| 5000/5000 [00:26<00:00, 185.40it/s]
# Autocorrelation time: omega_M = 29.6, omega_lambda = 29.7
# Chain length per walker (10000) is 336.3 times autocorrelation time
# Acceptance fraction: mean = 0.712, std = 0.008
# Best-fit omega_m = 0.367 +0.122 -0.115 (68% CI)
# Best-fit omega_lambda = 0.318 +0.186 -0.175 (68% CI)
# Fixed h = 0.7

# %% [markdown]
# ### Hubble diagram

# %% [markdown]
# In order to see if our fitted curves close to the theory, we plot a hubble diagram.
# Comparison models shown:
# - Planck 2018 ΛCDM: Standard cosmological model
# - Einstein-de Sitter: Matter-dominated universe
# - Empty Universe: Coasting cosmology
# - Best-fit MCMC: our fitted cosmological parameters
#
# The clear deviation from Einstein-de Sitter model demonstrates dark energy!

# %%
# Plot Hubble Diagram
if fitting_results:
    plt.figure(figsize=(12, 8))
    
    # Extract data from fitting results
    z_values = [r['redshift'] for r in fitting_results]
    mu_values = [r['mu'] for r in fitting_results]
    mu_errors = [r['mu_err'] for r in fitting_results]
    
    # Plot observed data points with error bars
    plt.errorbar(z_values, mu_values, yerr=mu_errors, fmt='o', 
                capsize=3, markersize=6, alpha=0.7, color='blue',
                label=f'Observed SNe Ia ({len(fitting_results)} objects)')
    
    # Create theoretical curves for comparison
    z_theory = np.logspace(-3, np.log10(max(z_values)*1.2), 100)
    
    # Standard ΛCDM model (Planck 2018 values)
    planck_pars = {'omega_M_0': 0.315, 'omega_lambda_0': 0.685, 'h': 0.674, 'w0': -1}
    mu_planck = cs.musn1a(z_theory, planck_pars)
    plt.plot(z_theory, mu_planck, 'r-', linewidth=2, alpha=0.8, 
             label='Planck 2018 ΛCDM (Ωₘ=0.315, ΩΛ=0.685)')
    
    # Einstein-de Sitter model (Ωₘ=1, ΩΛ=0)
    eds_pars = {'omega_M_0': 1.0, 'omega_lambda_0': 0.0, 'h': 0.7, 'w0': -1}
    mu_eds = cs.musn1a(z_theory, eds_pars)
    plt.plot(z_theory, mu_eds, 'g--', linewidth=2, alpha=0.8,
             label='Einstein-de Sitter (Ωₘ=1, ΩΛ=0)')
    
    # Empty universe model (Ωₘ=0, ΩΛ=0)
    empty_pars = {'omega_M_0': 0.0, 'omega_lambda_0': 0.0, 'h': 0.7, 'w0': -1}
    mu_empty = cs.musn1a(z_theory, empty_pars)
    plt.plot(z_theory, mu_empty, 'm:', linewidth=2, alpha=0.8,
             label='Empty Universe (Ωₘ=0, ΩΛ=0)')
    
    # If MCMC results are available, plot best-fit model
    try:
        if 'omegaM_50' in locals() and 'omegaL_50' in locals():
            best_fit_pars = {'omega_M_0': omegaM_50, 'omega_lambda_0': omegaL_50, 'h': fixed_h, 'w0': -1}
            mu_best_fit = cs.musn1a(z_theory, best_fit_pars)
            plt.plot(z_theory, mu_best_fit, 'orange', linewidth=3, alpha=0.9,
                     label=f'Best-fit MCMC (Ωₘ={omegaM_50:.3f}, ΩΛ={omegaL_50:.3f})')
    except NameError:
        pass
    
    # Formatting
    plt.xlabel('Redshift (z)', fontsize=14)
    plt.ylabel('Distance Modulus μ (mag)', fontsize=14)
    plt.title('Hubble Diagram: Type Ia Supernovae\nDistance Modulus vs Redshift', fontsize=16)
    plt.grid(True, alpha=0.3)
    plt.legend(fontsize=11, loc='lower right')
    
    # Set reasonable axis limits
    plt.xlim(0, max(z_values)*1.1)
    plt.ylim(min(mu_values)-1, max(mu_values)+1)
    
    # Add text box with analysis info
    textstr = f'Analysis Summary:\n• {len(fitting_results)} SNe Ia fitted\n• Redshift range: {min(z_values):.3f} - {max(z_values):.3f}\n• σᵢₙₜ = {sigma_int:.3f} mag'
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.8)
    plt.text(0.02, 0.98, textstr, transform=plt.gca().transAxes, fontsize=10,
             verticalalignment='top', bbox=props)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### MCMC on SN3 and CMB3

# %% [markdown]
# Finally, we cross our result with the Work Package CMB3. To do that, we implement use our Monte-Carlo Method on our data produced by Minuit (CSV file) and from the data produced by the other team.
#
# We can then obtain a density diagram for SNI and CMB and find the cosmological constraints of the universe of our data.

# %%
import camb
import numpy as np
import pandas as pd
import glob
import os
import emcee


# --- Load Supernovae Data ---
# Find the latest supernova CSV file
csv_pattern = 'supernova_fitting_results_*.csv'
csv_files = glob.glob(csv_pattern)
if not csv_files:
    raise FileNotFoundError(f"No CSV files found matching pattern: {csv_pattern}")
latest_csv = max(csv_files, key=os.path.getmtime)
print(f"Using CSV file: {latest_csv}")
df = pd.read_csv(latest_csv)
z = df['redshift'].values
mu_exp = df['mu'].values
sigma_mu_exp = df['mu_err'].values
sigma_int = 0.12  # Intrinsic scatter
sigma_total = np.sqrt(sigma_mu_exp**2 + sigma_int**2)  # Total uncertainty

# --- Load CMB Data ---
# Load observed CMB power spectrum data
ellvalues, dlexp, dlnoise = np.loadtxt('cl_forWP3.txt').T
deltal = 10
fsky = 0.1
var_dl = (2 / ((2 * ellvalues + 1) * deltal * fsky)) * dlexp**2
errors_bar = np.sqrt(dlnoise**2 + var_dl)  # Error bars for CMB data

# --- CMB Power Spectrum with CAMB ---
def generate_Dl(ell, param):
    """Generate CMB TT power spectrum (D_l) using CAMB."""
    h, om, ol = param
    # Check for reasonable parameter values to avoid CAMB crashes
    if max(abs(h), abs(om), abs(ol)) > 10:
        return [-1e9 for _ in range(len(ell))]
    try:
        pars = camb.CAMBparams()
        ombh2 = 0.02079  # Fixed baryon density
        pars.set_cosmology(
            H0=100 * h,
            ombh2=ombh2,
            omch2=om * h**2 - ombh2,
            omk=1 - (om + ol),  # Flatness condition
            tau=0.079  # Optical depth
        )
        pars.InitPower.set_params(As=np.exp(3.094) / 1e10, ns=0.9645)  # Primordial power spectrum
        lmax = int(max(ell)) + 50
        pars.set_for_lmax(lmax, lens_potential_accuracy=0)
        results = camb.get_results(pars)
        powers = results.get_cmb_power_spectra(pars, CMB_unit='muK')
        cl_tt = powers['total'][:, 0]  # TT power spectrum
        ell_camb = np.arange(len(cl_tt))
        dl_tt = ell_camb * (ell_camb + 1) * cl_tt / (2 * np.pi)  # Convert to D_l
        indices = ell.astype(int)
        return dl_tt[indices]
    except Exception as e:
        print(f"CAMB error: {e}")
        return [1e9 for _ in range(len(ell))]

def chi2_cmb(param):
    """Compute chi-squared for CMB data."""
    h, om, ol = param
    Dl_model = generate_Dl(ellvalues, (h, om, ol))
    Dl_model = np.array(Dl_model)
    if np.any(np.abs(Dl_model) > 1e8):  # Check for unphysical values
        return 1e10
    return np.sum((dlexp - Dl_model)**2 / errors_bar**2)

# --- Supernovae Model using cosmolib ---
def muPred(z, par):
    """Predict distance modulus using cs.musn1a from cosmolib."""
    return cs.musn1a(z, {'omega_M_0': par[0], 'omega_lambda_0': par[1], 'h': par[2], 'w0': -1})

def chi2_sn(par, z, mu_exp, sigma_total):
    """Compute chi-squared for supernova data."""
    mu_model = muPred(z, par)
    if np.any(np.isnan(mu_model)):  # Check for invalid model predictions
        return 1e10
    return np.sum((mu_model - mu_exp)**2 / sigma_total**2)

# --- Priors and Likelihoods ---
def log_prior(theta):
    """Define uniform priors for parameters."""
    omega_m, omega_lambda, h = theta
    if 0 < omega_m < 1 and 0 < omega_lambda < 1 and 0.5 < h < 0.9:
        return 0
    return -np.inf

def log_prob_sn(theta, z, mu_exp, sigma_total):
    """Log probability for SNe-only constraints."""
    omega_m, omega_lambda, h = theta
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    chi2sn = chi2_sn([omega_m, omega_lambda, h], z, mu_exp, sigma_total)
    return lp - 0.5 * chi2sn

def log_prob_cmb(theta):
    """Log probability for CMB-only constraints."""
    omega_m, omega_lambda, h = theta
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    chi2cmb = chi2_cmb([h, omega_m, omega_lambda])
    return lp - 0.5 * chi2cmb

def log_prob_joint(theta, z, mu_exp, sigma_total):
    """Log probability for joint SNe+CMB constraints."""
    omega_m, omega_lambda, h = theta
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    chi2sn = chi2_sn([omega_m, omega_lambda, h], z, mu_exp, sigma_total)
    chi2cmb = chi2_cmb([h, omega_m, omega_lambda])
    return lp - 0.5 * (chi2sn + chi2cmb)

# --- MCMC Setup ---
ndim = 3  # Number of parameters: omega_m, omega_lambda, h
nwalkers = 32  # Number of walkers
fixed_h = 0.7  # Fixed Hubble parameter (can be varied if desired)
guess = np.array([0.3, 0.7, fixed_h])  # Initial guess
p0 = [guess + 1e-2 * np.random.randn(ndim) for _ in range(nwalkers)]  # Initial positions

# Run MCMC for SNe
sampler_sn = emcee.EnsembleSampler(nwalkers, ndim, log_prob_sn, args=(z, mu_exp, sigma_total))
print("Burn-in for SNe...")
pos_sn, _, _ = sampler_sn.run_mcmc(p0, 500, progress=True)  # Burn-in
sampler_sn.reset()
print("Sampling for SNe...")
sampler_sn.run_mcmc(pos_sn, 2000, progress=True)  # Production run
chain_sn = sampler_sn.get_chain(flat=True)

# Run MCMC for CMB
sampler_cmb = emcee.EnsembleSampler(nwalkers, ndim, log_prob_cmb)
print("Burn-in for CMB...")
pos_cmb, _, _ = sampler_cmb.run_mcmc(p0, 500, progress=True)
sampler_cmb.reset()
print("Sampling for CMB...")
sampler_cmb.run_mcmc(pos_cmb, 2000, progress=True)  # Production run
chain_cmb = sampler_cmb.get_chain(flat=True)

# Run MCMC for Joint
sampler_joint = emcee.EnsembleSampler(nwalkers, ndim, log_prob_joint, args=(z, mu_exp, sigma_total))
print("Burn-in for joint...")
pos_joint, _, _ = sampler_joint.run_mcmc(p0, 500, progress=True)  # Burn-in
sampler_joint.reset()
print("Sampling for joint...")
sampler_joint.run_mcmc(pos_joint, 2000, progress=True)  # Production run
chain_joint = sampler_joint.get_chain(flat=True)

# --- Plotting Contours ---
def plot_contours(chain, color, label):
    """Plot 1σ and 2σ contours for a given MCMC chain."""
    omega_m = chain[:, 0]
    omega_lambda = chain[:, 1]
    hist, xedges, yedges = np.histogram2d(omega_m, omega_lambda, bins=50, density=True)
    x = (xedges[1:] + xedges[:-1]) / 2
    y = (yedges[1:] + yedges[:-1]) / 2
    sorted_hist = np.sort(hist.ravel())[::-1]
    cumsum = np.cumsum(sorted_hist)
    cumsum /= cumsum[-1]
    # Levels correspond to 1σ (68%) and 2σ (95%) confidence regions
    levels = [sorted_hist[np.where(cumsum >= 1 - np.exp(-0.5 * sigma**2))[0][0]] for sigma in [1, 2]]
    plt.contour(x, y, hist.T, levels=levels, colors=color)
    plt.plot([], [], color=color, label=label)

# Create the contour plot
plt.figure(figsize=(8, 6))
plot_contours(chain_sn, 'blue', 'SNe')
plot_contours(chain_cmb, 'red', 'CMB')
plot_contours(chain_joint, 'green', 'Joint')
plt.xlabel(r'$\Omega_m$', fontsize=14)
plt.ylabel(r'$\Omega_\Lambda$', fontsize=14)
plt.title('Constraints from SNe, CMB, and Joint', fontsize=16)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#   Cell In[35], line 139
#     pos_cmb, _, _ = sampler_cmb.run_mcmc(p0, 500, progress=True) Algebra Burn-in
#                                                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Brighter-slower effect and absolute magnitude laws

# %% [markdown]
# In addition, with a primar theoretical study, we are able to determine the optimum parameters ($\alpha$ and $M$) for the brighter-slower absolute magnitude laws.

# %%
c = 299792.458  # Speed of light in km/s
H0 = 70  # Hubble constant in km/s/Mpc

# Find the latest CSV file
csv_pattern = 'supernova_fitting_results_*.csv'
csv_files = glob.glob(csv_pattern)
if not csv_files:
    raise FileNotFoundError(f"No CSV files found matching pattern: {csv_pattern}")
latest_csv = max(csv_files, key=os.path.getmtime)

df = pd.read_csv(latest_csv)
z = df["redshift"].values
mu_obs = df["mu"].values
s = df["s"].values

def mu_th(z):
    dL = c*z / H0  # Approximation for z << 1
    return 5 * np.log10(dL * 10**6) + 25  # Theoretical distance modulus

def distance(params):
    alpha, M = params
    mu_corr = mu_obs - alpha * (s - 1) # Corrected distance modulus 
    mu_model = mu_th(z)
    return np.sum((mu_corr - mu_model - M)**2)

res = minimize(distance, x0=[0, 0])
alpha_fit, M_fit = res.x

print(f"alpha = {alpha_fit}, M = {M_fit}")
# Out:
# alpha = 1.2199142880028766, M = -29.413352276337
